# %%
import os
import numpy as np
import torch
import matplotlib.pyplot as plt
from deep_macrofin import PDEModel
from deep_macrofin import ActivationType, Comparator, EndogVar, EndogVarConditions, EndogEquation, LayerType

# %% [markdown]
# ## Model 1
# $$\frac{d x}{d t} = 2 * t, x(0)=1$$
# Solution: $x(t)=t^2 + 1$

# %%
ode1 = PDEModel("ode1", config={"num_epochs": 100, "lr": 1})
ode1.set_state(["t"], {"t": [-2., 2.]})
ode1.add_endog("x", {
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "hidden_units": [1, 2, 2, 1],
    "layer_type": LayerType.KAN,
    "activation_type": ActivationType.SiLU,
    "positive": False,
    "derivative_order": 2,
})
ode1.add_endog_equation(r"$\frac{\partial x}{\partial t} = 2 * t$", label="base_ode")
ode1.add_endog_condition("x", 
                              "x(SV)", {"SV": torch.zeros((1, 1))},
                              Comparator.EQ,
                              "1", {},
                              label="initial_condition")
print(ode1)
if not os.path.exists("./models/ode1.pt"):
    ode1.train_model_kan("./models", "ode1.pt", True)
    ode1.eval_model(True)
else:
    ode1.load_model(torch.load("./models/ode1.pt"))
    ode1.eval_model(True)
# Out:
# =============================Summary of Model ode1==============================
# Config: {
#  "batch_size": 100,
#  "num_epochs": 100,
#  "lr": 1
# }
# Latex Variable Mapping:
# {}
# User Defined Parameters:
# {}
#
# ================================State Variables=================================
# t: [-2.0, 2.0]
#
# =====================================Agents=====================================
#
# ================================Agent Conditions================================
#
# ==============================Endogenous Variables==============================
# Endogenous Variable Name: x
# EndogVar(
#   (model): KAN(
#     (biases): ModuleList(
#       (0-1): 2 x Linear(in_features=2, out_features=1, bias=False)
#       (2): Linear(in_features=1, out_features=1, bias=False)
#     )
#     (act_fun): ModuleList(
#       (0-2): 3 x KANLayer(
#         (base_fun): SiLU()
#       )
#     )
#     (base_fun): SiLU()
#     (symbolic_fun): ModuleList(
#       (0-2): 3 x Symbolic_KANLayer()
#     )
#   )
# )
# Num parameters: 149
# --------------------------------------------------------------------------------
#
# ========================Endogenous Variables Conditions=========================
# endogvar_x_cond_initial_condition: x(SV)=1 with LHS evaluated at SV=[[0.0]]
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ===================================Equations====================================
#
# ==============================Endogenous Equations==============================
# endogeq_base_ode:
# Raw input: $\frac{\partial x}{\partial t} = 2 * t$
# Parsed: x_t = 2 * t
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ==================================Constraints===================================
#
# =================================HJB Equations==================================
#
# ====================================Systems=====================================
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 22
#      20     ode1.eval_model(True)
#      21 else:
# ---> 22     ode1.load_model(torch.load("./models/ode1.pt"))
#      23     ode1.eval_model(True)
#
# File d:\UofT\Research\PDE-work\continuous-time-eco-models\venv\Lib\site-packages\torch\serialization.py:1025, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1023             except RuntimeError as e:
#    1024                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1025         return _load(opened_zipfile,
#    1026                      map_location,
#    1027                      pickle_module,
#    1028                      overall_storage=overall_storage,
#    1029                      **pickle_load_args)
#    1030 if mmap:
#    1031     f_name = "" if not isinstance(f, str) else f"{f}, "
#
# File d:\UofT\Research\PDE-work\continuous-time-eco-models\venv\Lib\site-packages\torch\serialization.py:1446, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1444 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1445 unpickler.persistent_load = persistent_load
# -> 1446 result = unpickler.load()
#    1448 torch._utils._validate_loaded_sparse_tensors()
#    1449 torch._C._log_api_usage_metadata(
#    1450     "torch.load.metadata", {"serialization_id": zip_file.serialization_id()}
#    1451 )
#
# File d:\UofT\Research\PDE-work\continuous-time-eco-models\venv\Lib\site-packages\torch\serialization.py:1439, in _load.<locals>.UnpicklerWrapper.find_class(self, mod_name, name)
#    1437         pass
#    1438 mod_name = load_module_mapping.get(mod_name, mod_name)
# -> 1439 return super().find_class(mod_name, name)
#
# ModuleNotFoundError: No module named 'deepMacroFin'

# %%
fig, ax = plt.subplots(1, 3, figsize=(16, 5))
t = np.linspace(-2, 2)
ax[0].plot(t, t**2+1, label="t^2+1")
ax[1].plot(t, 2*t, label="2*t")
ax[2].plot(t, np.ones_like(t) * 2, label="2")
ode1.endog_vars["x"].plot("x", {"t": [-2, 2]}, ax=ax[0])
ode1.endog_vars["x"].plot("x_t", {"t": [-2, 2]}, ax=ax[1])
ode1.endog_vars["x"].plot("x_tt", {"t": [-2, 2]}, ax=ax[2])
plt.subplots_adjust()
plt.show()

# %% [markdown]
# ## Model 2
# $$\frac{d x}{d t} = x, x(0)=1$$
# Solution: $x(t)=e^t$

# %%
ode2 = PDEModel("ode2", config={"num_epochs": 100, "lr": 1})
ode2.set_state(["t"], {"t": [-2., 2.]})
ode2.add_endog("x", {
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "hidden_units": [1, 2, 2, 1],
    "layer_type": LayerType.KAN,
    "activation_type": ActivationType.SiLU,
    "positive": False,
    "derivative_order": 2,
})
ode2.add_endog_equation("x_t=x", label="base_ode")
ode2.add_endog_condition("x", 
                              "x(SV)", {"SV": torch.zeros((1, 1))},
                              Comparator.EQ,
                              "1", {},
                              label="initial_condition")
print(ode2)
if not os.path.exists("./models/ode2.pt"):
    ode2.train_model_kan("./models", "ode2.pt", True)
    ode2.eval_model(True)
else:
    ode2.load_model(torch.load("./models/ode2.pt"))
    ode2.eval_model(True)
# Out:
# =============================Summary of Model ode2==============================
# Config: {
#  "batch_size": 100,
#  "num_epochs": 100,
#  "lr": 1
# }
# Latex Variable Mapping: {}
#
# ================================State Variables=================================
# t: [-2.0, 2.0]
#
# =====================================Agents=====================================
#
# ================================Agent Conditions================================
#
# ==============================Endogenous Variables==============================
# Endogenous Variable Name: x
# EndogVar(
#   (model): KAN(
#     (biases): ModuleList(
#       (0-1): 2 x Linear(in_features=2, out_features=1, bias=False)
#       (2): Linear(in_features=1, out_features=1, bias=False)
#     )
#     (act_fun): ModuleList(
#       (0-2): 3 x KANLayer(
#         (base_fun): SiLU()
#       )
#     )
#     (base_fun): SiLU()
#     (symbolic_fun): ModuleList(
#       (0-2): 3 x Symbolic_KANLayer()
#     )
#   )
# )
# Num parameters: 149
# --------------------------------------------------------------------------------
#
# ========================Endogenous Variables Conditions=========================
# endogvar_x_cond_initial_condition: x(SV)=1 with LHS evaluated at SV=[[0.0]]
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ===================================Equations====================================
#
# ==============================Endogenous Equations==============================
# endogeq_base_ode:
# Raw input: x_t=x;
# Parsed: x_t=x
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ==================================Constraints===================================
#
# =================================HJB Equations==================================
#
# ====================================Systems=====================================
#
#
# ====================================Training====================================
# Total loss: 0.0002: 100%|██████████| 100/100 [00:26<00:00,  3.79it/s]
# training finished, total time :: 26.37007236480713
# Model saved to ./models/ode2.pt
# ===================================Evaluating===================================
# loss :: endogeq_base_ode: 0.0001,
# endogvar_x_cond_initial_condition: 0.0000,
# total_loss: 0.0001

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 6))
t = np.linspace(-2, 2)
ax[0].plot(t, np.exp(t), label="e^t")
ax[1].plot(t, np.exp(t), label="e^t")
ax[2].plot(t, np.exp(t), label="e^t")
ode2.endog_vars["x"].plot("x", {"t": [-2, 2]}, ax=ax[0])
ode2.endog_vars["x"].plot("x_t", {"t": [-2, 2]}, ax=ax[1])
ode2.endog_vars["x"].plot("x_tt", {"t": [-2, 2]}, ax=ax[2])
plt.subplots_adjust()
plt.show()

# %% [markdown]
# ## Second order linear ODE
# $$y''+2y'+y=0, y(0)=1, y(1)=3e^{-1}$$
#
# Solution: $y=(1+2x)e^{-x}$
#
# **Note: ** when switched to $y''+4y'+4y=0, y(1)=3e^{-2}$, with solution $y=(1+2x)e^{-2x}$, it doesn't work too well.

# %%
ode3 = PDEModel("second_order_linear", config={"num_epochs": 100, "lr": 1})
ode3.set_state(["x"], {"x": [-1., 1.]})
ode3.add_endog("y", config={
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "hidden_units": [1, 5, 5, 1],
    "layer_type": LayerType.KAN,
    "activation_type": ActivationType.SiLU,
    "positive": False,
    "derivative_order": 2,
})
ode3.add_endog_equation("y_xx+2*y_x+y=0", label="base_ode")
ode3.add_endog_condition("y", 
                            "y(SV)", {"SV": torch.zeros((1, 1))},
                            Comparator.EQ,
                            "1", {},
                            label="ic1")
ode3.add_endog_condition("y", 
                            "y(SV)", {"SV": torch.ones((1, 1))},
                            Comparator.EQ,
                            "target", {"target": 3 * torch.exp(-torch.ones((1, 1)))},
                            label="ic2")
print(ode3)
if not os.path.exists("./models/ode3.pt"):
    ode3.train_model_kan("./models", "ode3.pt", True)
    ode3.eval_model(True)
else:
    ode3.load_model(torch.load("./models/ode3.pt"))
    ode3.eval_model(True)
# Out:
# ======================Summary of Model second_order_linear======================
# Config: {
#  "batch_size": 100,
#  "num_epochs": 100,
#  "lr": 1
# }
# Latex Variable Mapping: {}
#
# ================================State Variables=================================
# x: [-1.0, 1.0]
#
# =====================================Agents=====================================
#
# ================================Agent Conditions================================
#
# ==============================Endogenous Variables==============================
# Endogenous Variable Name: y
# EndogVar(
#   (model): KAN(
#     (biases): ModuleList(
#       (0-1): 2 x Linear(in_features=5, out_features=1, bias=False)
#       (2): Linear(in_features=1, out_features=1, bias=False)
#     )
#     (act_fun): ModuleList(
#       (0-2): 3 x KANLayer(
#         (base_fun): SiLU()
#       )
#     )
#     (base_fun): SiLU()
#     (symbolic_fun): ModuleList(
#       (0-2): 3 x Symbolic_KANLayer()
#     )
#   )
# )
# Num parameters: 641
# --------------------------------------------------------------------------------
#
# ========================Endogenous Variables Conditions=========================
# endogvar_y_cond_ic1: y(SV)=1 with LHS evaluated at SV=[[0.0]]
# Loss weight: 1.0
# --------------------------------------------------------------------------------
# endogvar_y_cond_ic2: y(SV)=target with LHS evaluated at SV=[[1.0]] and RHS evaluated at target=[[1.1036384105682373]]
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ===================================Equations====================================
#
# ==============================Endogenous Equations==============================
# endogeq_base_ode:
# Raw input: y_xx+2*y_x+y=0;
# Parsed: y_xx+2*y_x+y=0
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ==================================Constraints===================================
#
# =================================HJB Equations==================================
#
# ====================================Systems=====================================
#
#
# ====================================Training====================================
# Total loss: 0.1314: 100%|██████████| 100/100 [01:36<00:00,  1.03it/s]
# training finished, total time :: 96.63284802436829
# Model saved to ./models/ode3.pt
# ===================================Evaluating===================================
# loss :: endogeq_base_ode: 0.0197,
# endogvar_y_cond_ic1: 0.0262,
# endogvar_y_cond_ic2: 0.0638,
# total_loss: 0.1097

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 6))
x = np.linspace(-1, 1)
ax[0].plot(x, (1 + 2 * x) * np.exp(-x), label="(1+2x)e^{-x}")
ax[1].plot(x, (1 - 2 * x) * np.exp(-x), label="(1-2x)e^{-x}")
ax[2].plot(x, (-3 + 2 * x) * np.exp(-x), label="(-3+2x)e^{-x}")
ode3.endog_vars["y"].plot("y", {"x": [-1, 1]}, ax=ax[0])
ode3.endog_vars["y"].plot("y_x", {"x": [-1, 1]}, ax=ax[1])
ode3.endog_vars["y"].plot("y_xx", {"x": [-1, 1]}, ax=ax[2])
plt.subplots_adjust()
plt.show()

# %% [markdown]
# ## Second order linear ODE
# $$y''+4y'+4y=0, y(0)=1, y(1)=3e^{-2}$$
#
# Solution: $y=(1+2x)e^{-2x}$

# %%
ode4 = PDEModel("second_order_linear", config={"num_epochs": 100, "lr": 1})
ode4.set_state(["x"], {"x": [-1., 1.]})
ode4.add_endog("y", config={
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "hidden_units": [1, 5, 5, 1],
    "layer_type": LayerType.KAN,
    "activation_type": ActivationType.SiLU,
    "positive": False,
    "derivative_order": 2,
})
ode4.add_endog_equation("y_xx+4*y_x+4*y=0", label="base_ode")
ode4.add_endog_condition("y", 
                            "y(SV)", {"SV": torch.zeros((1, 1))},
                            Comparator.EQ,
                            "1", {},
                            label="ic1")
ode4.add_endog_condition("y", 
                            "y(SV)", {"SV": torch.ones((1, 1))},
                            Comparator.EQ,
                            "target", {"target": 3 * torch.exp(-2 * torch.ones((1, 1)))},
                            label="ic2")
print(ode4)
if not os.path.exists("./models/ode4.pt"):
    ode4.train_model_kan("./models", "ode4.pt", True)
    ode4.eval_model(True)
else:
    ode4.load_model(torch.load("./models/ode4.pt"))
    ode4.eval_model(True)
# Out:
# ======================Summary of Model second_order_linear======================
# Config: {
#  "batch_size": 100,
#  "num_epochs": 100,
#  "lr": 1
# }
# Latex Variable Mapping: {}
#
# ================================State Variables=================================
# x: [-1.0, 1.0]
#
# =====================================Agents=====================================
#
# ================================Agent Conditions================================
#
# ==============================Endogenous Variables==============================
# Endogenous Variable Name: y
# EndogVar(
#   (model): KAN(
#     (biases): ModuleList(
#       (0-1): 2 x Linear(in_features=5, out_features=1, bias=False)
#       (2): Linear(in_features=1, out_features=1, bias=False)
#     )
#     (act_fun): ModuleList(
#       (0-2): 3 x KANLayer(
#         (base_fun): SiLU()
#       )
#     )
#     (base_fun): SiLU()
#     (symbolic_fun): ModuleList(
#       (0-2): 3 x Symbolic_KANLayer()
#     )
#   )
# )
# Num parameters: 641
# --------------------------------------------------------------------------------
#
# ========================Endogenous Variables Conditions=========================
# endogvar_y_cond_ic1: y(SV)=1 with LHS evaluated at SV=[[0.0]]
# Loss weight: 1.0
# --------------------------------------------------------------------------------
# endogvar_y_cond_ic2: y(SV)=target with LHS evaluated at SV=[[1.0]] and RHS evaluated at target=[[0.406005859375]]
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ===================================Equations====================================
#
# ==============================Endogenous Equations==============================
# endogeq_base_ode:
# Raw input: y_xx+4*y_x+4*y=0;
# Parsed: y_xx+4*y_x+4*y=0
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ==================================Constraints===================================
#
# =================================HJB Equations==================================
#
# ====================================Systems=====================================
#
#
# ====================================Training====================================
# Total loss: 0.0419: 100%|██████████| 100/100 [01:35<00:00,  1.05it/s]
# training finished, total time :: 95.12593531608582
# Model saved to ./models/ode4.pt
# ===================================Evaluating===================================
# loss :: endogeq_base_ode: 0.0109,
# endogvar_y_cond_ic1: 0.0006,
# endogvar_y_cond_ic2: 0.0319,
# total_loss: 0.0434

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 6))
x = np.linspace(-1, 1)
ax[0].plot(x, (1 + 2 * x) * np.exp(-2*x), label="(1+2x)e^{-2x}")
ax[1].plot(x, -4 * x * np.exp(-2*x), label="-4xe^{-2x}")
ax[2].plot(x, (-4 + 8 * x) * np.exp(-2*x), label="(-4+8x)e^{-2x}")
ode4.endog_vars["y"].plot("y", {"x": [-1, 1]}, ax=ax[0])
ode4.endog_vars["y"].plot("y_x", {"x": [-1, 1]}, ax=ax[1])
ode4.endog_vars["y"].plot("y_xx", {"x": [-1, 1]}, ax=ax[2])
plt.subplots_adjust()
plt.show()

# %% [markdown]
# ## Cauchy-Euler Equations
# $$ x^2 y'' + 6xy' + 4y =0, y(1)=6, y(2)=\frac{5}{4}$$
#
# Solution: $y=4x^{-4} + 2 x^{-1}$

# %%
ode5 = PDEModel("cauchy_euler", config={"num_epochs": 100, "lr": 1})
ode5.set_state(["x"], {"x": [1., 2.]})
ode5.add_endog("y", config={
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "hidden_units": [1, 5, 5, 1],
    "layer_type": LayerType.KAN,
    "activation_type": ActivationType.SiLU,
    "positive": False,
    "derivative_order": 2,
})
ode5.add_endog_equation("x**2 * y_xx + 6*x*y_x + 4*y=0", label="base_ode")
ode5.add_endog_condition("y", 
                              "y(SV)", {"SV": torch.ones((1, 1))},
                              Comparator.EQ,
                              "6", {},
                              label="ic1")
ode5.add_endog_condition("y", 
                              "y(SV)", {"SV": 2 * torch.ones((1, 1))},
                              Comparator.EQ,
                              "5/4", {},
                              label="ic2")
print(ode5)
if not os.path.exists("./models/cauchy_euler.pt"):
    ode5.train_model("./models", "cauchy_euler.pt", True)
    ode5.eval_model(True)
else:
    ode5.load_model(torch.load("./models/cauchy_euler.pt"))
    ode5.eval_model(True)
# Out:
# =========================Summary of Model cauchy_euler==========================
# Config: {
#  "batch_size": 100,
#  "num_epochs": 100,
#  "lr": 1
# }
# Latex Variable Mapping: {}
#
# ================================State Variables=================================
# x: [1.0, 2.0]
#
# =====================================Agents=====================================
#
# ================================Agent Conditions================================
#
# ==============================Endogenous Variables==============================
# Endogenous Variable Name: y
# EndogVar(
#   (model): KAN(
#     (biases): ModuleList(
#       (0-1): 2 x Linear(in_features=5, out_features=1, bias=False)
#       (2): Linear(in_features=1, out_features=1, bias=False)
#     )
#     (act_fun): ModuleList(
#       (0-2): 3 x KANLayer(
#         (base_fun): SiLU()
#       )
#     )
#     (base_fun): SiLU()
#     (symbolic_fun): ModuleList(
#       (0-2): 3 x Symbolic_KANLayer()
#     )
#   )
# )
# Num parameters: 641
# --------------------------------------------------------------------------------
#
# ========================Endogenous Variables Conditions=========================
# endogvar_y_cond_ic1: y(SV)=6 with LHS evaluated at SV=[[1.0]]
# Loss weight: 1.0
# --------------------------------------------------------------------------------
# endogvar_y_cond_ic2: y(SV)=5/4 with LHS evaluated at SV=[[2.0]]
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ===================================Equations====================================
#
# ==============================Endogenous Equations==============================
# endogeq_base_ode:
# Raw input: x**2 * y_xx + 6*x*y_x + 4*y=0;
# Parsed: x**2 * y_xx + 6*x*y_x + 4*y=0
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ==================================Constraints===================================
#
# =================================HJB Equations==================================
#
# ====================================Systems=====================================
#
#
# ====================================Training====================================
# Total loss: 2003.0637: 100%|██████████| 100/100 [00:07<00:00, 12.91it/s]
# training finished, total time :: 7.75097131729126
# Model saved to ./models/cauchy_euler.pt
# ===================================Evaluating===================================
# loss :: endogeq_base_ode: 4.3217,
# endogvar_y_cond_ic1: 26.8515,
# endogvar_y_cond_ic2: 0.3514,
# total_loss: 31.5246

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 6))
x = np.linspace(1, 2)
ax[0].plot(x, 4*x**(-4) + 2 * x**(-1), label="4x^{-4}+2x^{-1}")
ax[1].plot(x, -16*x**(-5)-2*x**(-2), label="-16x^{-5}-2x^{-2}")
ax[2].plot(x, 80*x**(-6) + 4*x**(-3), label="80x^{-6}+4x^{-3}")
ode5.endog_vars["y"].plot("y", {"x": [1, 2]}, ax=ax[0])
ode5.endog_vars["y"].plot("y_x", {"x": [1, 2]}, ax=ax[1])
ode5.endog_vars["y"].plot("y_xx", {"x": [1, 2]}, ax=ax[2])
plt.subplots_adjust()
plt.show()
