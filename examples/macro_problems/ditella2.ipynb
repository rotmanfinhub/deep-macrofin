# %% [markdown]
# # Di Tella 2017
# This file replicates the results from [Di Tella 2017, Uncertainty Shocks and Balance Sheet Recessions](https://gsb-faculty.stanford.edu/sebastian-di-tella/files/2022/10/DiTella_Unc_Shocks_2556027.pdf)

# %%
import os
import numpy as np
import torch
import matplotlib.pyplot as plt
from deep_macrofin import PDEModel
from deep_macrofin import OptimizerType, SamplingMethod, LossReductionMethod, plot_loss_df, set_seeds

# %%
latex_var_mapping = {
    # variables
    r"\iota": "iota",
    r"\hat{e}": "e_hat",
    r"\hat{c}": "c_hat",
    r"\sigma_{x,1}": "sigxtop",
    r"\sigma_{x,2}": "sigxbot",
    r"\sigma_x": "sigx",
    r"\sigma_p": "sigp",
    r"\sigma_\xi": "sigxi",
    r"\sigma_\zeta": "sigzeta",
    r"\tilde{\sigma_n}": "signtilde",
    r"\sigma_n": "sign",
    r"\sigma_A": "sigA",
    r"\sigma_B": "sigB",
    r"\pi": "signxi",
    r"\sigma_w": "sigw",
    r"\mu_n": "mun",
    r"\mu_x": "mux",
    r"\mu_p": "mup",
    r"\mu_\xi": "muxi",
    r"\mu_\zeta": "muzeta",

    # agents
    r"\xi": "xi",
    r"\zeta": "zeta",

    # constants
    r"\bar{\sigma_v}": "sigv_mean",
    r"\sigma_v": "sigv",
    r"\mu_v": "muv",
    r"\sigma": "sigma",
    r"\lambda": "lbd",
    r"\bar{v}": "v_mean",
    r"\rho": "rho",
    r"\gamma": "gamma",
    r"\psi": "psi",
    r"\tau": "tau",
    r"\delta": "delta",
    r"\phi": "phi",
}

# %%
set_seeds(0)
pde_model = PDEModel("ditella", 
                     {"batch_size": 20,"num_epochs": 20000, "loss_log_interval": 100, "optimizer_type": OptimizerType.Adam, "sampling_method": SamplingMethod.FixedGrid}, 
                     latex_var_mapping)
pde_model.set_state(["x", "v"], {"x": [0.05, 0.95], "v": [0.05, 0.95]})
pde_model.add_agents(["xi", "zeta"], {"xi": {"positive": True}, "zeta": {"positive": True}})
pde_model.add_endog("p", {"positive": True})
pde_model.add_params({
    "a": 1,
    "sigma": 0.03,
    "lbd": 0.22,
    "v_mean": 0.24,
    "sigv_mean": -0.13,
    "rho": 0.05,
    "gamma": 5,
    "psi": 1.5,
    "tau": 0.,
    "A": 200,
    "B": 2,
    "delta": 0.05,
    "phi": 0.2
})
pde_model.add_equation(r"$g = \frac{1}{2*A} * p$")
pde_model.add_equation(r"$\iota = A * g^2$")
pde_model.add_equation(r"$\mu_v = \lambda * (\bar{v} - v)$")
pde_model.add_equation(r"$\sigma_v = \bar{\sigma_v} * \sqrt{v}$")
pde_model.add_equation(r"$\hat{e} = \rho^{1/\psi} * \xi^{(\psi-1)/\psi}$")
pde_model.add_equation(r"$\hat{c} = \rho^{1/\psi} * \zeta^{(\psi-1)/\psi}$")
pde_model.add_equation(r"$\sigma_{x,1} = (1-x) * x * \frac{1-\gamma}{\gamma * (\psi - 1)} * \left( \frac{1}{\xi} * \frac{\partial \xi}{\partial v} - \frac{1}{\zeta} * \frac{\partial \zeta}{\partial v} \right)$")
pde_model.add_equation(r"$\sigma_{x,2} = 1 - (1-x) * x * \frac{1-\gamma}{\gamma * (\psi - 1)} * \left( \frac{1}{\xi} * \frac{\partial \xi}{\partial x} - \frac{1}{\zeta} * \frac{\partial \zeta}{\partial x} \right)$")
pde_model.add_equation(r"$\sigma_x = \frac{\sigma_{x,1}}{\sigma_{x,2}} * \sigma_v$")
pde_model.add_equation(r"$\sigma_p = \frac{1}{p} * \left( \frac{\partial p}{\partial v} * \sigma_v + \frac{\partial p}{\partial x} * \sigma_x \right)$")
pde_model.add_equation(r"$\sigma_\xi = \frac{1}{\xi} * \left( \frac{\partial \xi}{\partial v} * \sigma_v + \frac{\partial \xi}{\partial x} * \sigma_x \right)$")
pde_model.add_equation(r"$\sigma_\zeta = \frac{1}{\zeta} * \left( \frac{\partial \zeta}{\partial v} * \sigma_v + \frac{\partial \zeta}{\partial x} * \sigma_x \right)$")
pde_model.add_equation(r"$k &= (\sigma_p + \sigma - \frac{1-\gamma}{\gamma * (\psi - 1)}) * (x * \sigma_\xi + (1 - x)* \sigma_\zeta) * \gamma$")
pde_model.add_equation(r"$k2 &= \frac{\gamma * \psi * v}{x}$")
pde_model.add_equation(r"$\sigma_A = \frac{k}{\gamma} + \frac{1-\gamma}{\gamma * (\psi - 1)} * \sigma_\xi$")
pde_model.add_equation(r"$\sigma_B = \frac{k}{\gamma} + \frac{1-\gamma}{\gamma * (\psi - 1)} * \sigma_\zeta$")
pde_model.add_equation(r"$v_A = \frac{k2}{\gamma}$")
pde_model.add_equation(r"$\mu_x = x*(1-x)*\left( \sigma_A * k + v_A * k2 - \frac{1}{\xi} - \tau - (\sigma_B * k - \frac{1}{\zeta} + \tau * \frac{x}{1-x}) - (\sigma_A - \sigma_B) * (\sigma + \sigma_p)\right)$")
pde_model.add_equation(r"$\mu_p = \frac{1}{p} * \left( \mu_v * \frac{\partial p}{\partial v} + \mu_x * \frac{\partial p}{\partial x} + \frac{1}{2} * \left( \sigma_v^2 * \frac{\partial^2 p}{\partial v^2} + 2 * \sigma_v * \sigma_x * \frac{\partial^2 p}{\partial v \partial x} + \sigma_x^2 * \frac{\partial^2 p}{\partial x^2} \right)\right)$")
pde_model.add_equation(r"$\mu_\xi = \frac{1}{\xi} * \left( \mu_v * \frac{\partial \xi}{\partial v} + \mu_x * \frac{\partial \xi}{\partial x} + \frac{1}{2} * \left( \sigma_v^2 * \frac{\partial^2 \xi}{\partial v^2} + 2 * \sigma_v * \sigma_x * \frac{\partial^2 \xi}{\partial v \partial x} + \sigma_x^2 * \frac{\partial^2 \xi}{\partial x^2} \right)\right)$")
pde_model.add_equation(r"$\mu_\zeta = \frac{1}{\zeta} * \left( \mu_v * \frac{\partial \zeta}{\partial v} + \mu_x * \frac{\partial \zeta}{\partial x} + \frac{1}{2} * \left( \sigma_v^2 * \frac{\partial^2 \zeta}{\partial v^2} + 2 * \sigma_v * \sigma_x * \frac{\partial^2 \zeta}{\partial v \partial x} + \sigma_x^2 * \frac{\partial^2 \zeta}{\partial x^2} \right)\right)$")
pde_model.add_equation(r"$r = \frac{a - \iota}{p} + g + \mu_p + \sigma * \sigma_p - k * (\sigma + \sigma_p) - \frac{\gamma}{x} * (\phi * v) ^2$")
pde_model.add_equation(r"$\sigma_n = \sigma + \sigma_p + \frac{\sigma_x}{x}$")
pde_model.add_equation(r"$\tilde{\sigma_n} = \frac{\phi}{x} * v$")
pde_model.add_equation(r"$\pi = \gamma * \sigma_n + (\gamma - 1) * \sigma_\xi$")
pde_model.add_equation(r"$\mu_n = r + \frac{\gamma}{x^2} * (\phi * v)^2 + \pi * \sigma_n$")

pde_model.add_endog_equation(r"$\hat{e} * x + \hat{c} * (1-x) = \frac{a - \iota}{p}$")
# pde_model.add_endog_equation(r"$\frac{a-\iota}{p} + g + \mu_p + \sigma * \sigma_p - r = (\sigma + \sigma_p) * \pi + \gamma * \frac{1}{x} * (\phi * v)^2$")

pde_model.add_hjb_equation(r"$\frac{\hat{e}^{1-\psi}}{1-\psi} * \rho * \xi^{\psi - 1} + \frac{\tau}{1-\gamma} * \left( \left(\frac{\zeta}{\xi}\right)^{1-\gamma}  - 1\right) + \mu_n - \hat{e} + \mu_\xi - \frac{\gamma}{2} * \left( \sigma_n^2 + \sigma_\xi^2 - 2 * \frac{1-\gamma}{\gamma} * \sigma_n * \sigma_\xi + \tilde{\sigma_n}^2 \right) - \frac{\rho}{1-\psi}$")
pde_model.add_hjb_equation(r"$\frac{\hat{c}^{1-\psi}}{1-\psi} * \rho * \zeta^{\psi - 1} + \mu_n - \hat{c} + \mu_\zeta - \frac{\gamma}{2} * \left( \sigma_n^2 + \sigma_\zeta^2 - 2 * \frac{1-\gamma}{\gamma} * \sigma_n * \sigma_\zeta + \tilde{\sigma_n}^2 \right) - \frac{\rho}{1-\psi}$")
print(pde_model)
if not os.path.exists("./models/ditella_decouple/model.pt"):
    pde_model.train_model("./models/ditella_decouple", "model.pt", True)
    pde_model.load_model(torch.load("./models/ditella_decouple/model_best.pt"))
    pde_model.eval_model(True)
else:
    pde_model.load_model(torch.load("./models/ditella_decouple/model_best.pt"))
    pde_model.eval_model(True)
# Out:
# ============================Summary of Model ditella============================
# Config: {
#  "batch_size": 20,
#  "num_epochs": 20000,
#  "lr": 0.001,
#  "loss_log_interval": 100,
#  "optimizer_type": "Adam",
#  "sampling_method": "FixedGrid"
# }
# Latex Variable Mapping:
# {
#  "\\iota": "iota",
#  "\\hat{e}": "e_hat",
#  "\\hat{c}": "c_hat",
#  "\\sigma_{x,1}": "sigxtop",
#  "\\sigma_{x,2}": "sigxbot",
#  "\\sigma_x": "sigx",
#  "\\sigma_p": "sigp",
#  "\\sigma_\\xi": "sigxi",
#  "\\sigma_\\zeta": "sigzeta",
#  "\\tilde{\\sigma_n}": "signtilde",
#  "\\sigma_n": "sign",
#  "\\sigma_A": "sigA",
#  "\\sigma_B": "sigB",
#  "\\pi": "signxi",
#  "\\sigma_w": "sigw",
#  "\\mu_n": "mun",
#  "\\mu_x": "mux",
#  "\\mu_p": "mup",
#  "\\mu_\\xi": "muxi",
#  "\\mu_\\zeta": "muzeta",
#  "\\xi": "xi",
#  "\\zeta": "zeta",
#  "\\bar{\\sigma_v}": "sigv_mean",
#  "\\sigma_v": "sigv",
#  "\\mu_v": "muv",
#  "\\sigma": "sigma",
#  "\\lambda": "lbd",
#  "\\bar{v}": "v_mean",
#  "\\rho": "rho",
#  "\\gamma": "gamma",
#  "\\psi": "psi",
#  "\\tau": "tau",
#  "\\delta": "delta",
#  "\\phi": "phi"
# }
# User Defined Parameters:
# {
#  "a": 1,
#  "sigma": 0.03,
#  "lbd": 0.22,
#  "v_mean": 0.24,
#  "sigv_mean": -0.13,
#  "rho": 0.05,
#  "gamma": 5,
#  "psi": 1.5,
#  "tau": 0.0,
#  "A": 200,
#  "B": 2,
#  "delta": 0.05,
#  "phi": 0.2
# }
#
# ================================State Variables=================================
# x: [0.05, 0.95]
# v: [0.05, 0.95]
#
# =====================================Agents=====================================
# Agent Name: xi
# Agent(
#   (model): Sequential(
#     (linear_0): Linear(in_features=2, out_features=30, bias=True)
#     (activation_0): Tanh()
#     (linear_1): Linear(in_features=30, out_features=30, bias=True)
#     (activation_1): Tanh()
#     (linear_2): Linear(in_features=30, out_features=30, bias=True)
#     (activation_2): Tanh()
#     (linear_3): Linear(in_features=30, out_features=30, bias=True)
#     (activation_3): Tanh()
#     (final_layer): Linear(in_features=30, out_features=1, bias=True)
#     (positive_act): Softplus(beta=1.0, threshold=20.0)
#   )
# )
# Num parameters: 2911
# --------------------------------------------------------------------------------
# Agent Name: zeta
# Agent(
#   (model): Sequential(
#     (linear_0): Linear(in_features=2, out_features=30, bias=True)
#     (activation_0): Tanh()
#     (linear_1): Linear(in_features=30, out_features=30, bias=True)
#     (activation_1): Tanh()
#     (linear_2): Linear(in_features=30, out_features=30, bias=True)
#     (activation_2): Tanh()
#     (linear_3): Linear(in_features=30, out_features=30, bias=True)
#     (activation_3): Tanh()
#     (final_layer): Linear(in_features=30, out_features=1, bias=True)
#     (positive_act): Softplus(beta=1.0, threshold=20.0)
#   )
# )
# Num parameters: 2911
# --------------------------------------------------------------------------------
#
# ================================Agent Conditions================================
#
# ==============================Endogenous Variables==============================
# Endogenous Variable Name: p
# EndogVar(
#   (model): Sequential(
#     (linear_0): Linear(in_features=2, out_features=30, bias=True)
#     (activation_0): Tanh()
#     (linear_1): Linear(in_features=30, out_features=30, bias=True)
#     (activation_1): Tanh()
#     (linear_2): Linear(in_features=30, out_features=30, bias=True)
#     (activation_2): Tanh()
#     (linear_3): Linear(in_features=30, out_features=30, bias=True)
#     (activation_3): Tanh()
#     (final_layer): Linear(in_features=30, out_features=1, bias=True)
#     (positive_act): Softplus(beta=1.0, threshold=20.0)
#   )
# )
# Num parameters: 2911
# --------------------------------------------------------------------------------
#
# ========================Endogenous Variables Conditions=========================
#
# ===================================Equations====================================
# eq_1:
# Raw input: $g = \frac{1}{2*A} * p$
# Parsed: g=(1)/(2*A) * p
# eq_2:
# Raw input: $\iota = A * g^2$
# Parsed: iota=A * g**(2)
# eq_3:
# Raw input: $\mu_v = \lambda * (\bar{v} - v)$
# Parsed: muv=lbd * (v_mean - v)
# eq_4:
# Raw input: $\sigma_v = \bar{\sigma_v} * \sqrt{v}$
# Parsed: sigv=sigv_mean * sqrt(v)
# eq_5:
# Raw input: $\hat{e} = \rho^{1/\psi} * \xi^{(\psi-1)/\psi}$
# Parsed: e_hat=rho**(1/psi) * xi**((psi-1)/psi)
# eq_6:
# Raw input: $\hat{c} = \rho^{1/\psi} * \zeta^{(\psi-1)/\psi}$
# Parsed: c_hat=rho**(1/psi) * zeta**((psi-1)/psi)
# eq_7:
# Raw input: $\sigma_{x,1} = (1-x) * x * \frac{1-\gamma}{\gamma * (\psi - 1)} * \left( \frac{1}{\xi} * \frac{\partial \xi}{\partial v} - \frac{1}{\zeta} * \frac{\partial \zeta}{\partial v} \right)$
# Parsed: sigxtop=(1-x) * x * (1-gamma)/(gamma * (psi - 1)) * ( (1)/(xi) * xi_v - (1)/(zeta) * zeta_v )
# eq_8:
# Raw input: $\sigma_{x,2} = 1 - (1-x) * x * \frac{1-\gamma}{\gamma * (\psi - 1)} * \left( \frac{1}{\xi} * \frac{\partial \xi}{\partial x} - \frac{1}{\zeta} * \frac{\partial \zeta}{\partial x} \right)$
# Parsed: sigxbot=1 - (1-x) * x * (1-gamma)/(gamma * (psi - 1)) * ( (1)/(xi) * xi_x - (1)/(zeta) * zeta_x )
# eq_9:
# Raw input: $\sigma_x = \frac{\sigma_{x,1}}{\sigma_{x,2}} * \sigma_v$
# Parsed: sigx=(sigxtop)/(sigxbot) * sigv
# eq_10:
# Raw input: $\sigma_p = \frac{1}{p} * \left( \frac{\partial p}{\partial v} * \sigma_v + \frac{\partial p}{\partial x} * \sigma_x \right)$
# Parsed: sigp=(1)/(p) * ( p_v * sigv + p_x * sigx )
# eq_11:
# Raw input: $\sigma_\xi = \frac{1}{\xi} * \left( \frac{\partial \xi}{\partial v} * \sigma_v + \frac{\partial \xi}{\partial x} * \sigma_x \right)$
# Parsed: sigxi=(1)/(xi) * ( xi_v * sigv + xi_x * sigx )
# eq_12:
# Raw input: $\sigma_\zeta = \frac{1}{\zeta} * \left( \frac{\partial \zeta}{\partial v} * \sigma_v + \frac{\partial \zeta}{\partial x} * \sigma_x \right)$
# Parsed: sigzeta=(1)/(zeta) * ( zeta_v * sigv + zeta_x * sigx )
# eq_13:
# Raw input: $k &= (\sigma_p + \sigma - \frac{1-\gamma}{\gamma * (\psi - 1)}) * (x * \sigma_\xi + (1 - x)* \sigma_\zeta) * \gamma$
# Parsed: k=(sigp + sigma - (1-gamma)/(gamma * (psi - 1))) * (x * sigxi + (1 - x)* sigzeta) * gamma
# eq_14:
# Raw input: $k2 &= \frac{\gamma * \psi * v}{x}$
# Parsed: k2=(gamma * psi * v)/(x)
# eq_15:
# Raw input: $\sigma_A = \frac{k}{\gamma} + \frac{1-\gamma}{\gamma * (\psi - 1)} * \sigma_\xi$
# Parsed: sigA=(k)/(gamma) + (1-gamma)/(gamma * (psi - 1)) * sigxi
# eq_16:
# Raw input: $\sigma_B = \frac{k}{\gamma} + \frac{1-\gamma}{\gamma * (\psi - 1)} * \sigma_\zeta$
# Parsed: sigB=(k)/(gamma) + (1-gamma)/(gamma * (psi - 1)) * sigzeta
# eq_17:
# Raw input: $v_A = \frac{k2}{\gamma}$
# Parsed: v_A=(k2)/(gamma)
# eq_18:
# Raw input: $\mu_x = x*(1-x)*\left( \sigma_A * k + v_A * k2 - \frac{1}{\xi} - \tau - (\sigma_B * k - \frac{1}{\zeta} + \tau * \frac{x}{1-x}) - (\sigma_A - \sigma_B) * (\sigma + \sigma_p)\right)$
# Parsed: mux=x*(1-x)*( sigA * k + v_A * k2 - (1)/(xi) - tau - (sigB * k - (1)/(zeta) + tau * (x)/(1-x)) - (sigA - sigB) * (sigma + sigp))
# eq_19:
# Raw input: $\mu_p = \frac{1}{p} * \left( \mu_v * \frac{\partial p}{\partial v} + \mu_x * \frac{\partial p}{\partial x} + \frac{1}{2} * \left( \sigma_v^2 * \frac{\partial^2 p}{\partial v^2} + 2 * \sigma_v * \sigma_x * \frac{\partial^2 p}{\partial v \partial x} + \sigma_x^2 * \frac{\partial^2 p}{\partial x^2} \right)\right)$
# Parsed: mup=(1)/(p) * ( muv * p_v + mux * p_x + (1)/(2) * ( sigv**(2) * p_vv + 2 * sigv * sigx * p_vx + sigx**(2) * p_xx ))
# eq_20:
# Raw input: $\mu_\xi = \frac{1}{\xi} * \left( \mu_v * \frac{\partial \xi}{\partial v} + \mu_x * \frac{\partial \xi}{\partial x} + \frac{1}{2} * \left( \sigma_v^2 * \frac{\partial^2 \xi}{\partial v^2} + 2 * \sigma_v * \sigma_x * \frac{\partial^2 \xi}{\partial v \partial x} + \sigma_x^2 * \frac{\partial^2 \xi}{\partial x^2} \right)\right)$
# Parsed: muxi=(1)/(xi) * ( muv * xi_v + mux * xi_x + (1)/(2) * ( sigv**(2) * xi_vv + 2 * sigv * sigx * xi_vx + sigx**(2) * xi_xx ))
# eq_21:
# Raw input: $\mu_\zeta = \frac{1}{\zeta} * \left( \mu_v * \frac{\partial \zeta}{\partial v} + \mu_x * \frac{\partial \zeta}{\partial x} + \frac{1}{2} * \left( \sigma_v^2 * \frac{\partial^2 \zeta}{\partial v^2} + 2 * \sigma_v * \sigma_x * \frac{\partial^2 \zeta}{\partial v \partial x} + \sigma_x^2 * \frac{\partial^2 \zeta}{\partial x^2} \right)\right)$
# Parsed: muzeta=(1)/(zeta) * ( muv * zeta_v + mux * zeta_x + (1)/(2) * ( sigv**(2) * zeta_vv + 2 * sigv * sigx * zeta_vx + sigx**(2) * zeta_xx ))
# eq_22:
# Raw input: $r = \frac{a - \iota}{p} + g + \mu_p + \sigma * \sigma_p - k * (\sigma + \sigma_p) - \frac{\gamma}{x} * (\phi * v) ^2$
# Parsed: r=(a - iota)/(p) + g + mup + sigma * sigp - k * (sigma + sigp) - (gamma)/(x) * (phi * v) **(2)
# eq_23:
# Raw input: $\sigma_n = \sigma + \sigma_p + \frac{\sigma_x}{x}$
# Parsed: sign=sigma + sigp + (sigx)/(x)
# eq_24:
# Raw input: $\tilde{\sigma_n} = \frac{\phi}{x} * v$
# Parsed: signtilde=(phi)/(x) * v
# eq_25:
# Raw input: $\pi = \gamma * \sigma_n + (\gamma - 1) * \sigma_\xi$
# Parsed: signxi=gamma * sign + (gamma - 1) * sigxi
# eq_26:
# Raw input: $\mu_n = r + \frac{\gamma}{x^2} * (\phi * v)^2 + \pi * \sigma_n$
# Parsed: mun=r + (gamma)/(x**(2)) * (phi * v)**(2) + signxi * sign
#
# ==============================Endogenous Equations==============================
# endogeq_1:
# Raw input: $\hat{e} * x + \hat{c} * (1-x) = \frac{a - \iota}{p}$
# Parsed: e_hat * x + c_hat * (1-x)=(a - iota)/(p)
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ==================================Constraints===================================
#
# =================================HJB Equations==================================
# hjbeq_1:
# Raw input: $\frac{\hat{e}^{1-\psi}}{1-\psi} * \rho * \xi^{\psi - 1} + \frac{\tau}{1-\gamma} * \left( \left(\frac{\zeta}{\xi}\right)^{1-\gamma}  - 1\right) + \mu_n - \hat{e} + \mu_\xi - \frac{\gamma}{2} * \left( \sigma_n^2 + \sigma_\xi^2 - 2 * \frac{1-\gamma}{\gamma} * \sigma_n * \sigma_\xi + \tilde{\sigma_n}^2 \right) - \frac{\rho}{1-\psi}$;
# Parsed: (e_hat**(1-psi))/(1-psi) * rho * xi**(psi - 1) + (tau)/(1-gamma) * ( ((zeta)/(xi))**(1-gamma)  - 1) + mun - e_hat + muxi - (gamma)/(2) * ( sign**(2) + sigxi**(2) - 2 * (1-gamma)/(gamma) * sign * sigxi + signtilde**(2) ) - (rho)/(1-psi)
# Loss weight: 1.0
# --------------------------------------------------------------------------------
# hjbeq_2:
# Raw input: $\frac{\hat{c}^{1-\psi}}{1-\psi} * \rho * \zeta^{\psi - 1} + \mu_n - \hat{c} + \mu_\zeta - \frac{\gamma}{2} * \left( \sigma_n^2 + \sigma_\zeta^2 - 2 * \frac{1-\gamma}{\gamma} * \sigma_n * \sigma_\zeta + \tilde{\sigma_n}^2 \right) - \frac{\rho}{1-\psi}$;
# Parsed: (c_hat**(1-psi))/(1-psi) * rho * zeta**(psi - 1) + mun - c_hat + muzeta - (gamma)/(2) * ( sign**(2) + sigzeta**(2) - 2 * (1-gamma)/(gamma) * sign * sigzeta + signtilde**(2) ) - (rho)/(1-psi)
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ====================================Systems=====================================
#
#
# Model loaded
# ===================================Evaluating===================================
# loss :: endogeq_1: 0.0001,
# hjbeq_1: 0.0012,
# hjbeq_2: 0.0003,
# total_loss: 0.0016

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 6), subplot_kw={"projection": "3d"})
pde_model.agents["xi"].plot("xi", {"x": [0.05, 0.95], "nu": [0.05, 0.95]}, ax=ax[0])
pde_model.agents["zeta"].plot("zeta", {"x": [0.05, 0.95], "nu": [0.05, 0.95]}, ax=ax[1])
pde_model.endog_vars["p"].plot("p", {"x": [0.05, 0.95], "nu": [0.05, 0.95]}, ax=ax[2])
plt.subplots_adjust()
plt.show()

# %%
plot_loss_df(fn="./models/ditella_decouple/model_min_loss.csv", loss_plot_fn="./models/ditella_decouple/model_min_loss.png")
pde_model.plot_vars([r"$\xi$", r"$\zeta$", "p", 
                     r"$\sigma+\sigma_p = \sigma + \sigma_p$", r"$\pi$", "r"], ncols=3)

# %%
fig, ax = plt.subplots(2, 3, figsize=(18, 12))
for x_val, linestyle in [(0.05, "-"), (0.1, ":"), (0.2, "--")]:
    sv = torch.ones((100, 2), device=pde_model.device) * x_val
    sv[:, 1] = torch.linspace(0.05, 0.95, 100)
    for i, sv_name in enumerate(pde_model.state_variables):
        pde_model.variable_val_dict[sv_name] = sv[:, i:i+1]
    pde_model.update_variables(sv)
    sigsigp = pde_model.variable_val_dict["sigma"] + pde_model.variable_val_dict["sigp"]
    pi = pde_model.variable_val_dict["signxi"]
    r = pde_model.variable_val_dict["r"]
    ax[0][0].plot(sv[:, 1].detach().cpu().numpy(), sigsigp.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"x={x_val}")
    ax[0][1].plot(sv[:, 1].detach().cpu().numpy(), pi.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"x={x_val}")
    ax[0][2].plot(sv[:, 1].detach().cpu().numpy(), r.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"x={x_val}")
    ax[0][0].set_title(r"$\sigma+\sigma_p$")
    ax[0][1].set_title(r"$\pi$")
    ax[0][2].set_title("r")
    ax[0][0].legend()
    ax[0][1].legend()
    ax[0][2].legend()

for v_val, linestyle in [(0.1, "-"), (0.25, ":"), (0.6, "--")]:
    sv = torch.ones((100, 2), device=pde_model.device) * v_val
    sv[:, 0] = torch.linspace(0.05, 0.95, 100)
    for i, sv_name in enumerate(pde_model.state_variables):
        pde_model.variable_val_dict[sv_name] = sv[:, i:i+1]
    pde_model.update_variables(sv)
    sigsigp = pde_model.variable_val_dict["sigma"] + pde_model.variable_val_dict["sigp"]
    pi = pde_model.variable_val_dict["signxi"]
    r = pde_model.variable_val_dict["r"]
    ax[1][0].plot(sv[:, 0].detach().cpu().numpy(), sigsigp.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"v={v_val}")
    ax[1][1].plot(sv[:, 0].detach().cpu().numpy(), pi.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"v={v_val}")
    ax[1][2].plot(sv[:, 0].detach().cpu().numpy(), r.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"v={v_val}")
    ax[1][0].set_title(r"$\sigma+\sigma_p$")
    ax[1][1].set_title(r"$\pi$")
    ax[1][2].set_title("r")
    ax[1][0].legend()
    ax[1][1].legend()
    ax[1][2].legend()

# %% [markdown]
# ## Change to MAE and train more epochs

# %%
pde_model.set_loss_reduction("hjbeq_1", LossReductionMethod.MAE)
if not os.path.exists("./models/ditella_decouple/model2.pt"):
    pde_model.train_model("./models/ditella_decouple", "model2.pt", True)
    pde_model.load_model(torch.load("./models/ditella_decouple/model2_best.pt"))
    pde_model.eval_model(True)
else:
    pde_model.load_model(torch.load("./models/ditella_decouple/model2_best.pt"))
    pde_model.eval_model(True)
# Out:
# Model loaded
# ===================================Evaluating===================================
# loss :: endogeq_1: 0.0000,
# hjbeq_1: 0.0023,
# hjbeq_2: 0.0001,
# total_loss: 0.0024

# %%
plot_loss_df(fn="./models/ditella_decouple/model2_min_loss.csv", loss_plot_fn="./models/ditella_decouple/model2_min_loss.png")
pde_model.plot_vars([r"$\xi$", r"$\zeta$", "p", 
                     r"$\sigma+\sigma_p = \sigma + \sigma_p$", r"$\pi$", "r"], ncols=3)

# %%
fig, ax = plt.subplots(2, 3, figsize=(18, 12))
for x_val, linestyle in [(0.05, "-"), (0.1, ":"), (0.2, "--")]:
    sv = torch.ones((100, 2), device=pde_model.device) * x_val
    sv[:, 1] = torch.linspace(0.05, 0.95, 100)
    for i, sv_name in enumerate(pde_model.state_variables):
        pde_model.variable_val_dict[sv_name] = sv[:, i:i+1]
    pde_model.update_variables(sv)
    sigsigp = pde_model.variable_val_dict["sigma"] + pde_model.variable_val_dict["sigp"]
    pi = pde_model.variable_val_dict["signxi"]
    r = pde_model.variable_val_dict["r"]
    ax[0][0].plot(sv[:, 1].detach().cpu().numpy(), sigsigp.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"x={x_val}")
    ax[0][1].plot(sv[:, 1].detach().cpu().numpy(), pi.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"x={x_val}")
    ax[0][2].plot(sv[:, 1].detach().cpu().numpy(), r.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"x={x_val}")
    ax[0][0].set_title(r"$\sigma+\sigma_p$")
    ax[0][1].set_title(r"$\pi$")
    ax[0][2].set_title("r")
    ax[0][0].legend()
    ax[0][1].legend()
    ax[0][2].legend()

for v_val, linestyle in [(0.1, "-"), (0.25, ":"), (0.6, "--")]:
    sv = torch.ones((100, 2), device=pde_model.device) * v_val
    sv[:, 0] = torch.linspace(0.05, 0.95, 100)
    for i, sv_name in enumerate(pde_model.state_variables):
        pde_model.variable_val_dict[sv_name] = sv[:, i:i+1]
    pde_model.update_variables(sv)
    sigsigp = pde_model.variable_val_dict["sigma"] + pde_model.variable_val_dict["sigp"]
    pi = pde_model.variable_val_dict["signxi"]
    r = pde_model.variable_val_dict["r"]
    ax[1][0].plot(sv[:, 0].detach().cpu().numpy(), sigsigp.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"v={v_val}")
    ax[1][1].plot(sv[:, 0].detach().cpu().numpy(), pi.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"v={v_val}")
    ax[1][2].plot(sv[:, 0].detach().cpu().numpy(), r.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"v={v_val}")
    ax[1][0].set_title(r"$\sigma+\sigma_p$")
    ax[1][1].set_title(r"$\pi$")
    ax[1][2].set_title("r")
    ax[1][0].legend()
    ax[1][1].legend()
    ax[1][2].legend()
