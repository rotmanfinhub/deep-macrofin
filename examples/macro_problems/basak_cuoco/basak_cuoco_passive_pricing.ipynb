# %%
import os
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
from deep_macrofin import PDEModel
from deep_macrofin import Comparator, OptimizerType, LossReductionMethod, set_seeds
from tqdm import tqdm
from torch.func import jacrev, hessian, vmap

# %%
class PDEModelCustomSample(PDEModel):
    def __init__(self, name, config, latex_var_mapping={}):
        super().__init__(name, config, latex_var_mapping)
        self.sample = self.sample_custom

        # if you want to use scheduler, uncomment the following two lines
        # self.OnTrainingStart += self.add_scheduler
        # self.OnTrainingStep += self.scheduler_step
        self.OnTrainingStep += self.change_batch_size

        # if you want to plot the results during training, uncomment the following line
        # self.OnTrainingStep += self.plot_results


    def add_scheduler(self, **kwargs):
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            self.optimizer, mode='min', factor=0.70, patience=1000, 
            threshold=1e-4, min_lr=1e-6
        )

    def scheduler_step(self, **kwargs):
        total_loss = 0
        for loss_label, loss in self.loss_val_dict.items():
            total_loss += self.loss_weight_dict[loss_label] * torch.where(loss.isnan(), 0.0, loss)
        self.scheduler.step(total_loss)
    
    def sample_simplex(self, epoch):
        eps = 0.05
        max_sum = 0.99
        alpha = torch.ones(len(self.state_variables), device=self.device)
        samples = torch.distributions.Dirichlet(alpha).sample((self.batch_size,))
        samples = eps + (max_sum - len(self.state_variables) * eps) * samples
        return samples[:, :-1]

    def sample_custom(self, epoch):
        xs = self.sample_simplex(epoch)
        alpha_p_max = self.variable_val_dict["alphap_max"]
        alpha_p_min = self.variable_val_dict["alphap_min"]
        alphap = torch.rand(xs.shape[0], 1, device=self.device) * (alpha_p_max - alpha_p_min) + alpha_p_min
        return torch.cat((xs, alphap), dim=1)

    def change_batch_size(self, **kwargs):
        if kwargs["epoch"] > 10000:
            self.config["batch_size"] = 500
            self.batch_size = 500
        else:
            self.config["batch_size"] = 200
            self.batch_size = 200

    # def plot_results(self, **kwargs):
    #     if kwargs["epoch"] % 10000 == 0:
    #         os.makedirs(f"{model_path}/plots", exist_ok=True)
    #         plot_results(self, f"{model_path}/plots", suffix=f"_{kwargs['epoch']}")

    def closure(self, SV):
        for i, sv_name in enumerate(self.state_variables):
            self.variable_val_dict[sv_name] = SV[:, i:i+1]
        self.variable_val_dict["SV"] = SV
        self.update_variables(SV)
        self.loss_fn()
        total_loss = 0
        for loss_label, loss in self.loss_val_dict.items():
            total_loss += self.loss_weight_dict[loss_label] * torch.where(loss.isnan(), 0.0, loss)

        self.optimizer.zero_grad()
        total_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.optimizer.param_groups[0]['params'], max_norm=1.0)
        return total_loss

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model_path = "./models/GP_4_30"
# in the following, follow the sequence u, c, p
params = {
    "gamma": torch.tensor([4, 4, 12], device= device), # risk aversion
    "rho" : 0.05, # Discount rate
    "alpha_bar" : 1000.95, # lev. constrained ceiling
    "alphap_bar" : 0.0 , # Alpha passive agent 
    "theta" : 0.0, # Alpha drift
    "sig_alphap": torch.tensor([0, 0], device= device), # vol of passive demand share
    "nu": 0.5, # correlation
    "mu": 0.0183, # mean of the lognormal distribution of the asset return 
    "sigma": torch.tensor([0.0357, 0.00], device=device), # fundamental vol
    "kappa": 0.00, # death intensity
    "omega": torch.tensor([0.25, 0.25, 0.50], device= device), # mass of each agent
    "alphap_min": 0.0, # minimum alpha for passive agent
    "alphap_max": 0.0, # maximum alpha for passive
}
params["psi"] = torch.tensor([1.5, 1.5, 1.5], device= device) # intertemporal elasticity of substitution

# %%
# --------------------------------------------------
# Core unknown functions and derivatives
# --------------------------------------------------
def compute_y(SV, compute_xiu, compute_xic, compute_xip):
    xu = SV[:,0:1]
    xc = SV[:,1:2]
    xp = 1 - xu - xc
    xiu = compute_xiu(SV)
    xic = compute_xic(SV)
    xip = compute_xip(SV)
    y = xu*xiu+xc*xic+xp*xip
    return y

def compute_dydx(SV, compute_xiu, compute_xic, compute_xip, compute_y):
    dy_dx = vmap(jacrev(lambda sv: compute_y(sv.unsqueeze(0), compute_xiu, compute_xic, compute_xip).squeeze(0)))(SV)
    return dy_dx

def compute_d2ydx2(SV, compute_xiu, compute_xic, compute_xip, compute_y):
    d2y_dx2 = vmap(hessian(lambda sv: compute_y(sv.unsqueeze(0), compute_xiu, compute_xic, compute_xip).squeeze(0)))(SV)
    return d2y_dx2

def merge_xi(xiu, xic, xip):
    # xiu is of shape (B, 1)
    return torch.cat([xiu, xic, xip], dim=1)

def merge_xi_jac(xiu_Jac, xic_Jac, xip_Jac):
    # xiu_Jac is of shape (B, 1, n_state)
    return torch.cat([xiu_Jac, xic_Jac, xip_Jac], dim=1)

def merge_xi_Hess(xiu_Hess, xic_Hess, xip_Hess):
    # xiu_Hess is of shape (B, 1, n_state, n_state)
    return torch.cat([xiu_Hess, xic_Hess, xip_Hess], dim=1)

# --------------------------------------------------
# Exogenous dividend shock and passive-share shock
# --------------------------------------------------
def compute_sigma_a(alphap, sig_alphap, nu):
    sig_alphap1 = sig_alphap[0]
    return torch.cat((
        torch.ones_like(alphap) * (sig_alphap1 * nu),
        torch.ones_like(alphap) * (sig_alphap1 * (1 - nu**2)**0.5)
    ), dim=1)

# --------------------------------------------------
# Derive sigma_y exactly from y and the state dynamics
# (y + A) sigma_y = A sigma + y_a sigma_a
# --------------------------------------------------
def compute_sigy(xu, xc, y, dy_dx, alphau, alphac, sigma, sigma_a):
    y_xu = dy_dx[:, 0, 0:1]
    y_xc = dy_dx[:, 0, 1:2]
    y_a = dy_dx[:, 0, 2:3]
    A = y_xu * xu * (alphau - 1) + y_xc * xc * (alphac - 1)
    sigy = (A * sigma.reshape(1, 2) + y_a * sigma_a) / (y + A + 1e-8)
    return sigy

# --------------------------------------------------
# State diffusion matrix (level diffusion)
# --------------------------------------------------
def compute_sigx(xu, xc, alphau, alphac, sigR, sig_a):
    sig_xu = xu * (alphau - 1) * sigR
    sig_xc = xc * (alphac - 1) * sigR
    return torch.stack((sig_xu, sig_xc, sig_a), dim=1)

def compute_sigx_geo(alphau, alphac, sigR, sig_a, alphap):
    return torch.stack(
        (
            (alphau - 1) * sigR,
            (alphac - 1) * sigR,
            sig_a / (alphap + 1e-8)
        ),
        dim=1
    )

def compute_varsigma(gamma, sigxi, sigR, psi):
    gamma = gamma.reshape(1, 3)
    psi = psi.reshape(1, 3)
    varsigma = (
        (1-1/gamma)/(1-psi+1e-8) 
        * torch.sum(sigxi * sigR.unsqueeze(1), dim=2) / torch.sum(sigR**2, axis=1,keepdim=True)
    ) # TODO: if psi=1/gamma, what's the point of the first term?
    return varsigma

# --------------------------------------------------
# State drifts in levels
# --------------------------------------------------
def compute_mux(xu, xc, alphau, alphac, alphap, xiu, xic, y, q, sigR, kappa, omega, theta, alphap_bar):
    omegau = omega[0]
    omegac = omega[1]
    sigR_sq = torch.sum(sigR**2, dim=1, keepdim=True)
    mu_xu = xu * (y - xiu + (1.0 - alphau) * (1 - q) * sigR_sq) + kappa * (omegau - xu)
    mu_xc = xc * (y - xic + (1.0 - alphac) * (1 - q) * sigR_sq) + kappa * (omegac - xc)
    mu_alphap = theta * (alphap_bar - alphap)
    return torch.cat((mu_xu, mu_xc, mu_alphap), dim=1)

# --------------------------------------------------
# Ito for mu_y and mu_xi (geometric drifts)
# --------------------------------------------------
def compute_a_mat(xsigx):
    return torch.einsum("bij,bkj->bik", xsigx, xsigx)

def compute_muxi(xi, xi_Jac, xi_Hess, mux, a_mat):
    muxiAll_1 = torch.einsum("bij,bj->bi", xi_Jac, mux) / xi
    muxiAll_2 = 0.5 * torch.einsum("bijk,bkj->bi", xi_Hess, a_mat) / xi
    return muxiAll_1 + muxiAll_2

def compute_muy(y, dy_dx, d2y_dx2, mux, a_mat):
    muy_1 = torch.einsum("bij,bj->bi", dy_dx, mux) / y
    muy_2 = 0.5 * torch.einsum("bijk,bkj->bi", d2y_dx2, a_mat) / y
    return muy_1 + muy_2

# --------------------------------------------------
# Price drift
# --------------------------------------------------
def compute_muP(muy, sigy, sigma, mu):
    sigma_T = sigma.reshape(1, 2)  # (1, 2) to match sigmaAll.T shape
    muP = mu - muy + torch.sum(sigy * (sigy - sigma_T), dim=1, keepdim=True)
    return muP

# --------------------------------------------------
# HJB residuals
# --------------------------------------------------
def compute_hjb(gamma, muxi, sigxi, sigR, psi, r, eta, alphaAll, sigR_norm, xi, rho):
    gamma = gamma.reshape(1, 3)
    psi = psi.reshape(1, 3)
    hjb = (
        rho * psi 
        + (1 - psi) * (r + eta * alphaAll * sigR_norm - gamma/2 * (alphaAll * sigR_norm)**2) 
        + muxi 
        + (1-gamma) * torch.sum(sigxi * sigR.unsqueeze(1), dim=2) * alphaAll 
        + (psi - gamma)/(1-psi+1e-8) *torch.sum(sigxi**2,axis=2)/2 
        - xi
    )
    hjb = hjb / rho
    hjb_err = torch.mean(hjb**2,dim=0).sum()
    return hjb_err

def compute_market_clearing(xu, xc, xp, alphau, alphac, alphap):
    return xu * alphau + xc * alphac + xp * alphap

def compute_foc_c(q, gamma, sigR_norm, varsigma, alpha_bar):
    gamma_c = gamma[1]
    compare1 = q / gamma_c  - varsigma[:,1:2]
    compare2 = alpha_bar/(sigR_norm+1e-8)
    return torch.min(compare1, compare2)

def compute_foc_p(q, gamma, varsigma):
    gamma_p = gamma[2]
    return q / gamma_p - varsigma[:,2:3]

def compute_pricing_need_alphap(xc, xu, xp, varsigma, sigR_norm, gamma):
    NUM = (1 + xu*varsigma[:,0:1] +  xc*varsigma[:,1:2] + xp*varsigma[:,2:3]) * sigR_norm**2
    DEN = xu/gamma[0] + xc/gamma[1] + xp/gamma[2]
    return NUM / (DEN + 1e-8)

def compute_pricing(xc, xu, xp, varsigma, sigR_norm, gamma):
    NUM = (1 + xu*varsigma[:,0:1] +  xc*varsigma[:,1:2]) * sigR_norm**2
    DEN = xu/gamma[0] + xc/gamma[1]
    return NUM / (DEN + 1e-8)

def get_model(model_path: str, params: dict, model_size: list[int], passive_pricing=False):
    set_seeds(42)
    model = PDEModelCustomSample("aliens_3d", config={"batch_size": 500, "num_epochs": 20000, "optimizer_type": OptimizerType.Adam, "lr": 1e-3})
    model.set_state(["xu", "xc", "alphap"], 
        {"xu": [0, 1], "xc": [0, 1], "alphap": [params["alphap_min"], params["alphap_max"]]}
    )
    model.add_params(params)
    model.register_functions([
        compute_y, compute_dydx, compute_d2ydx2,
        merge_xi, merge_xi_jac, merge_xi_Hess, 
        compute_sigma_a,
        compute_sigy,
        compute_sigx,
        compute_sigx_geo,
        compute_varsigma,
        compute_mux,
        compute_a_mat,
        compute_muxi,
        compute_muy,
        compute_muP,
        compute_hjb,
        compute_market_clearing,
        compute_foc_c,
        compute_foc_p,
        compute_pricing_need_alphap,
        compute_pricing,
    ])
    model.add_agent("xiu", config={"hidden_units": model_size, "batch_jac_hes": True, "positive": True})
    model.add_agent("xic", config={"hidden_units": model_size, "batch_jac_hes": True, "positive": True})
    model.add_agent("xip", config={"hidden_units": model_size, "batch_jac_hes": True, "positive": True})
    model.add_endog("alphau", config={"hidden_units": model_size, "derivative_order": 0})
    model.add_endog("alphac", config={"hidden_units": model_size, "derivative_order": 0})
    if passive_pricing:
        model.add_endog("alphap_pred", config={"hidden_units": model_size, "derivative_order": 0})
    else:
        model.add_equation("alphap_pred = alphap")
    model.add_equations([
        "xp=1-xu-xc", # (B, 1)
        "alphaAll=torch.cat((alphau,alphac,alphap_pred),dim=1)", # (B, 3)
        "y=xu*xiu+xc*xic+xp*xip", # (B, 1)
        "dy_dx=compute_dydx(SV, compute_xiu, compute_xic, compute_xip, compute_y)", # (B, 1, 3)
        "d2y_dx2=compute_d2ydx2(SV, compute_xiu, compute_xic, compute_xip, compute_y)", # (B, 1, 3, 3)
        "xi=merge_xi(xiu, xic, xip)",
        "xi_Jac=merge_xi_jac(xiu_Jac, xic_Jac, xip_Jac)",
        "xi_Hess=merge_xi_Hess(xiu_Hess, xic_Hess, xip_Hess)",
        "sigma_a=compute_sigma_a(alphap_pred, sig_alphap, nu)",
        "sigy=compute_sigy(xu, xc, y, dy_dx, alphau, alphac, sigma, sigma_a)",
        "sigR=sigma.reshape(1,2)-sigy", # (B, 2)
        "sigR_norm=torch.sqrt(torch.sum(sigR ** 2, dim=1, keepdim=True))", # (B, 1)
        "sigx=compute_sigx(xu, xc, alphau, alphac, sigR, sigma_a)",
        "sigx_geo=compute_sigx_geo(alphau, alphac, sigR, sigma_a, alphap)",
        "sigxi=torch.bmm(xi_Jac/(xi.unsqueeze(-1)+1e-8), sigx)", # (B, 3, 2)
        "varsigma=compute_varsigma(gamma, sigxi, sigR, psi)", # (B, 3)
        "q=gamma[0]*(alphau+varsigma[:,0:1])", # (B, 1)
        "pi=q*sigR_norm**2", # (B, 1) # Derive pi from the u-FOC exactly.
        "eta=q*sigR_norm", # (B, 1)
        "mux=compute_mux(xu, xc, alphau, alphac, alphap, xiu, xic, y, q, sigR, kappa, omega, theta, alphap_bar)", # (B, 3)
        "mux_=mux/(SV+1e-8)", 
        "a_mat=compute_a_mat(sigx)", # (B, 3, 3)
        "muxi=compute_muxi(xi, xi_Jac, xi_Hess, mux, a_mat)", # (B, 3)
        "muy=compute_muy(y, dy_dx, d2y_dx2, mux, a_mat)", # (B, 1)
        "muP=compute_muP(muy,sigy,sigma,mu)", # (B, 1)
        "r=y+muP-pi", # short rate implied by y and sigma_y
        "hjb=compute_hjb(gamma, muxi, sigxi, sigR, psi, r, eta, alphaAll, sigR_norm, xi, rho)", # (B, 1)
    ])

    model.add_endog_equation("compute_market_clearing(xu, xc, xp, alphau, alphac, alphap_pred)=1")
    model.add_endog_equation("alphac=compute_foc_c(q, gamma, sigR_norm, varsigma, alpha_bar)")
    if passive_pricing:
        model.add_endog_equation("pi=compute_pricing_need_alphap(xc, xu, xp, varsigma, sigR_norm, gamma)")
        model.add_endog_equation("alphap_pred=compute_foc_p(q, gamma, varsigma)")
    else:
        model.add_endog_equation("pi=compute_pricing(xc, xu, xp, varsigma, sigR_norm, gamma)")
    model.add_hjb_equation("hjb", loss_reduction=LossReductionMethod.NONE)

    if not os.path.exists(f"{model_path}/model.pt"):
        model.train_model(model_path, "model.pt", True)
    model.load_model(torch.load(f"{model_path}/model_best.pt", weights_only=False))
    return model

# %%
model = get_model(model_path, params, [30]*4, passive_pricing=True)
# Out:
# Model loaded

# %%
def generate_state_grid(n_grid=50):
    """Generate a grid of state variables (xc, xu, alphap)"""
    
    # Create grid for xc and xu
    xc_grid = np.linspace(0.05, 0.95, n_grid)
    xu_grid = np.linspace(0.05, 0.95, n_grid)
    
    # For alphap, use a range based on params
    alphap_grid = np.linspace(params['alphap_min'], params['alphap_max'], max(10, n_grid // 5))
    
    # If alphap range is zero (constant), just use a single value
    if params['alphap_min'] == params['alphap_max']:
        alphap_grid = np.array([params['alphap_min']])
    
    # Create meshgrid
    xc_mesh, xu_mesh, alphap_mesh = np.meshgrid(xc_grid, xu_grid, alphap_grid)
    
    # Flatten
    xc_flat = xc_mesh.flatten()
    xu_flat = xu_mesh.flatten()
    alphap_flat = alphap_mesh.flatten()
    
    # Filter: xc + xu < 1 (xp must be positive)
    valid_mask = (xc_flat + xu_flat) < 0.99
    
    xc_valid = xc_flat[valid_mask]
    xu_valid = xu_flat[valid_mask]
    alphap_valid = alphap_flat[valid_mask]
    
    return xc_valid, xu_valid, alphap_valid

numerical = pd.DataFrame({
    "x_low": pd.read_csv("models/gp_numerical/x_low.csv").iloc[10:, 1].values.flatten(),
    "r":     pd.read_csv("models/gp_numerical/r_cheb.csv").iloc[10:, 1].values.flatten(),
    "y":     pd.read_csv("models/gp_numerical/y_cheb.csv").iloc[10:, 1].values.flatten(),
    "pi":    pd.read_csv("models/gp_numerical/pi_cheb.csv").iloc[10:, 1].values.flatten(),
})

xc_valid, xu_valid, alphap_valid = generate_state_grid(n_grid=50)
SV = torch.stack((
    torch.tensor(xc_valid, device=model.device, dtype=torch.float32),
    torch.tensor(xu_valid, device=model.device, dtype=torch.float32),
    torch.tensor(alphap_valid, device=model.device, dtype=torch.float32),
), dim=1)
SV.requires_grad_(True)
x_plot = SV[:, 0].detach().cpu().numpy().reshape(-1) + SV[:, 1].detach().cpu().numpy().reshape(-1)
for i, sv_name in enumerate(model.state_variables):
    model.variable_val_dict[sv_name] = SV[:, i:i+1]
model.variable_val_dict["SV"] = SV
model.update_variables(SV)

r = model.variable_val_dict["r"].detach().cpu().numpy().reshape(-1)
y = model.variable_val_dict["y"].detach().cpu().numpy().reshape(-1)
pi = model.variable_val_dict["pi"].detach().cpu().numpy().reshape(-1)
alphac = model.variable_val_dict["alphac"].detach().cpu().numpy().reshape(-1)
alphau = model.variable_val_dict["alphau"].detach().cpu().numpy().reshape(-1)

fig, ax = plt.subplots(1, 5, figsize=(26, 6))
ax[0].scatter(x_plot, r, color="red", s=4, label="NN")
ax[0].plot(numerical["x_low"], numerical["r"], color="blue", label="Perturbation")
ax[0].set_xlabel("$x_u+x_c$")
ax[0].set_ylabel("r")
ax[0].legend()

ax[1].scatter(x_plot, pi, color="red", s=4, label="NN")
ax[1].plot(numerical["x_low"], numerical["pi"], color="blue", label="Perturbation")
ax[1].set_xlabel("$x_u+x_c$")
ax[1].set_ylabel("$\\pi$")
ax[1].legend()

ax[2].scatter(x_plot, y, color="red", s=4, label="NN")
ax[2].plot(numerical["x_low"], numerical["y"], color="blue", label="Perturbation")
ax[2].set_xlabel("$x_u+x_c$")
ax[2].set_ylabel("y")
ax[2].legend()

ax[3].scatter(x_plot, alphac, color="red", s=4, label="NN")
ax[3].set_xlabel("$x_u+x_c$")
ax[3].set_ylabel("$\\alpha_c$")

ax[4].scatter(x_plot, alphau, color="red", s=4, label="NN")
ax[4].set_xlabel("$x_u+x_c$")
ax[4].set_ylabel("$\\alpha_u$")
plt.show()
