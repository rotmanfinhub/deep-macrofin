# %% [markdown]
# # Di Tella 2017
# This file replicates the results from [Di Tella 2017, Uncertainty Shocks and Balance Sheet Recessions](https://gsb-faculty.stanford.edu/sebastian-di-tella/files/2022/10/DiTella_Unc_Shocks_2556027.pdf)

# %%
import os
import numpy as np
import torch
import matplotlib.pyplot as plt
from deep_macrofin import PDEModel
from deep_macrofin import ActivationType, OptimizerType, SamplingMethod, plot_loss_df, set_seeds

# %%
latex_var_mapping = {
    # variables
    r"\iota": "iota",
    r"\hat{e}": "e_hat",
    r"\hat{c}": "c_hat",
    r"\sigma_{x,1}": "sigxtop",
    r"\sigma_{x,2}": "sigxbot",
    r"\sigma_x": "sigx",
    r"\sigma_p": "sigp",
    r"\sigma_\xi": "sigxi",
    r"\sigma_\zeta": "sigzeta",
    r"\tilde{\sigma_n}": "signtilde",
    r"\sigma_n": "sign",
    r"\pi": "signxi",
    r"\sigma_w": "sigw",
    r"\mu_n": "mun",
    r"\mu_x": "mux",
    r"\mu_p": "mup",
    r"\mu_\xi": "muxi",
    r"\mu_\zeta": "muzeta",
    r"\mu_w": "muw",

    # agents
    r"\xi": "xi",
    r"\zeta": "zeta",

    # constants
    r"\bar{\sigma_v}": "sigv_mean",
    r"\sigma_v": "sigv",
    r"\mu_v": "muv",
    r"\sigma": "sigma",
    r"\lambda": "lbd",
    r"\bar{v}": "v_mean",
    r"\rho": "rho",
    r"\gamma": "gamma",
    r"\psi": "psi",
    r"\tau": "tau",
    r"\delta": "delta",
    r"\phi": "phi",
}

# %%
set_seeds(0)
pde_model = PDEModel("ditella", 
                     {"batch_size": 50, "num_epochs": 10000, "loss_log_interval": 100, 
                      "optimizer_type": OptimizerType.Adam, "sampling_method": SamplingMethod.FixedGrid,
                      "loss_adaption_interval": 100}, 
                     latex_var_mapping)
pde_model.set_state(["x", "v"], {"x": [0.05, 0.95], "v": [0.05, 0.95]})
pde_model.add_agents(["xi", "zeta"], 
                     {"xi": {
                         "positive": True, 
                        }, 
                      "zeta": {
                          "positive": True, 
                          }
                     })
pde_model.add_endogs(["p", "r"], 
                     {"p": {
                         "positive": True, 
                         },
                     })
pde_model.add_params({
    "a": 1,
    "sigma": 0.0125,
    "lbd": 1.38,
    "v_mean": 0.25,
    "sigv_mean": -0.17,
    "rho": 0.0665,
    "gamma": 5,
    "psi": 0.5,
    "tau": 1.15,
    "phi": 0.2,

    "A": 53.2,
    "B": -0.8668571428571438,
    "delta": 0.05,
})
pde_model.add_equation(r"$g &= \frac{1}{2*A} * (p - B) - \delta$") # g &= \frac{1}{2*A} * (p - B) - \delta
pde_model.add_equation(r"$\iota &= A * (g+\delta)^2 + B * (g+\delta)$") # \iota &= A * (g+\delta)^2 + B * (g+\delta)
pde_model.add_equation(r"$\mu_v &= \lambda * (\bar{v} - v)$")
pde_model.add_equation(r"$\sigma_v &= \bar{\sigma_v} * \sqrt{v}$")
pde_model.add_equation(r"$\hat{e} &= \rho^{1/\psi} * \xi^{(\psi-1)/\psi}$")
pde_model.add_equation(r"$\hat{c} &= \rho^{1/\psi} * \zeta^{(\psi-1)/\psi}$")
pde_model.add_equation(r"$\sigma_{x,1} &= (1-x) * x * \frac{1-\gamma}{\gamma} * \left( \frac{1}{\xi} * \frac{\partial \xi}{\partial v} - \frac{1}{\zeta} * \frac{\partial \zeta}{\partial v} \right)$")
pde_model.add_equation(r"$\sigma_{x,2} &= 1 - (1-x) * x * \frac{1-\gamma}{\gamma} * \left( \frac{1}{\xi} * \frac{\partial \xi}{\partial x} - \frac{1}{\zeta} * \frac{\partial \zeta}{\partial x} \right)$")
pde_model.add_equation(r"$\sigma_x &= \frac{\sigma_{x,1}}{\sigma_{x,2}} * \sigma_v$")
pde_model.add_equation(r"$\sigma_p &= \frac{1}{p} * \left( \frac{\partial p}{\partial v} * \sigma_v + \frac{\partial p}{\partial x} * \sigma_x \right)$")
pde_model.add_equation(r"$\sigma_\xi &= \frac{1}{\xi} * \left( \frac{\partial \xi}{\partial v} * \sigma_v + \frac{\partial \xi}{\partial x} * \sigma_x \right)$")
pde_model.add_equation(r"$\sigma_\zeta &= \frac{1}{\zeta} * \left( \frac{\partial \zeta}{\partial v} * \sigma_v + \frac{\partial \zeta}{\partial x} * \sigma_x \right)$")
pde_model.add_equation(r"$\sigma_n &= \sigma + \sigma_p + \frac{\sigma_x}{x}$")
pde_model.add_equation(r"$\pi &= \gamma * \sigma_n + (\gamma-1) * \sigma_\xi$")
pde_model.add_equation(r"$\sigma_w &= \frac{\pi}{\gamma} - \frac{\gamma-1}{\gamma} *  \sigma_\zeta$")
pde_model.add_equation(r"$\mu_w &= r + \pi * \sigma_w$")
pde_model.add_equation(r"$\mu_n &= r + \frac{\gamma}{x^2} * (\phi * v)^2 + \pi * \sigma_n$")
pde_model.add_equation(r"$\tilde{\sigma_n} &= \frac{\phi}{x} * v$")
pde_model.add_equation(r"$\mu_x &= x * \left(\mu_n - \hat{e} - \tau + \frac{a-\iota}{p} - r - \pi * (\sigma+\sigma_p) - \frac{\gamma}{x} * (\phi * v)^2 + (\sigma + \sigma_p)^2 - \sigma_n * (\sigma + \sigma_p)\right)$")
pde_model.add_equation(r"$\mu_p &= \frac{1}{p} * \left( \mu_v * \frac{\partial p}{\partial v} + \mu_x * \frac{\partial p}{\partial x} + \frac{1}{2} * \left( \sigma_v^2 * \frac{\partial^2 p}{\partial v^2} + 2 * \sigma_v * \sigma_x * \frac{\partial^2 p}{\partial v \partial x} + \sigma_x^2 * \frac{\partial^2 p}{\partial x^2} \right)\right)$")
pde_model.add_equation(r"$\mu_\xi &= \frac{1}{\xi} * \left( \mu_v * \frac{\partial \xi}{\partial v} + \mu_x * \frac{\partial \xi}{\partial x} + \frac{1}{2} * \left( \sigma_v^2 * \frac{\partial^2 \xi}{\partial v^2} + 2 * \sigma_v * \sigma_x * \frac{\partial^2 \xi}{\partial v \partial x} + \sigma_x^2 * \frac{\partial^2 \xi}{\partial x^2} \right)\right)$")
pde_model.add_equation(r"$\mu_\zeta &= \frac{1}{\zeta} * \left( \mu_v * \frac{\partial \zeta}{\partial v} + \mu_x * \frac{\partial \zeta}{\partial x} + \frac{1}{2} * \left( \sigma_v^2 * \frac{\partial^2 \zeta}{\partial v^2} + 2 * \sigma_v * \sigma_x * \frac{\partial^2 \zeta}{\partial v \partial x} + \sigma_x^2 * \frac{\partial^2 \zeta}{\partial x^2} \right)\right)$")

pde_model.add_endog_equation(r"$a - \iota &= p * (\hat{e} * x + \hat{c} * (1-x))$")
pde_model.add_endog_equation(r"$\sigma + \sigma_p &= \sigma_n * x + \sigma_w * (1-x)$")
pde_model.add_endog_equation(r"$\frac{a-\iota}{p} + g + \mu_p + \sigma * \sigma_p - r &= (\sigma + \sigma_p) * \pi + \gamma * \frac{1}{x} * (\phi * v)^2$")

pde_model.add_hjb_equation(r"$\frac{\hat{e}^{1-\psi}}{1-\psi} * \rho * \xi^{\psi-1} + \frac{\tau}{1-\gamma} * \left(\left(\frac{\zeta}{\xi} \right)^{1-\gamma}-1 \right) + \mu_n - \hat{e} + \mu_\xi - \frac{\gamma}{2} * \left( \sigma_n^2 + \sigma_\xi^2 - 2 * \frac{1-\gamma}{\gamma} * \sigma_n * \sigma_\xi + \tilde{\sigma_n}^2 \right) - \frac{\rho}{1-\psi}$")
pde_model.add_hjb_equation(r"$\frac{\hat{c}^{1-\psi}}{1-\psi} * \rho * \zeta^{\psi-1} + \mu_w - \hat{c} + \mu_\zeta - \frac{\gamma}{2} * \left( \sigma_w^2 + \sigma_\zeta^2 - 2 * \frac{1-\gamma}{\gamma} * \sigma_w * \sigma_\zeta \right) - \frac{\rho}{1-\psi}$")
print(pde_model)
if not os.path.exists("./models/ditella_with_investments2/model.pt"):
    pde_model.train_model("./models/ditella_with_investments2", "model.pt", True)
    pde_model.load_model(torch.load("./models/ditella_with_investments2/model_best.pt"))
    pde_model.eval_model(True)
else:
    pde_model.load_model(torch.load("./models/ditella_with_investments2/model_best.pt"))
    pde_model.eval_model(True)
# Out:
# ============================Summary of Model ditella============================
# Config: {
#  "batch_size": 50,
#  "num_epochs": 10000,
#  "lr": 0.001,
#  "loss_log_interval": 100,
#  "optimizer_type": "Adam",
#  "sampling_method": "FixedGrid",
#  "loss_adaption_interval": 100
# }
# Latex Variable Mapping:
# {
#  "\\iota": "iota",
#  "\\hat{e}": "e_hat",
#  "\\hat{c}": "c_hat",
#  "\\sigma_{x,1}": "sigxtop",
#  "\\sigma_{x,2}": "sigxbot",
#  "\\sigma_x": "sigx",
#  "\\sigma_p": "sigp",
#  "\\sigma_\\xi": "sigxi",
#  "\\sigma_\\zeta": "sigzeta",
#  "\\tilde{\\sigma_n}": "signtilde",
#  "\\sigma_n": "sign",
#  "\\pi": "signxi",
#  "\\sigma_w": "sigw",
#  "\\mu_n": "mun",
#  "\\mu_x": "mux",
#  "\\mu_p": "mup",
#  "\\mu_\\xi": "muxi",
#  "\\mu_\\zeta": "muzeta",
#  "\\mu_w": "muw",
#  "\\xi": "xi",
#  "\\zeta": "zeta",
#  "\\bar{\\sigma_v}": "sigv_mean",
#  "\\sigma_v": "sigv",
#  "\\mu_v": "muv",
#  "\\sigma": "sigma",
#  "\\lambda": "lbd",
#  "\\bar{v}": "v_mean",
#  "\\rho": "rho",
#  "\\gamma": "gamma",
#  "\\psi": "psi",
#  "\\tau": "tau",
#  "\\delta": "delta",
#  "\\phi": "phi"
# }
# User Defined Parameters:
# {
#  "a": 1,
#  "sigma": 0.0125,
#  "lbd": 1.38,
#  "v_mean": 0.25,
#  "sigv_mean": -0.17,
#  "rho": 0.0665,
#  "gamma": 5,
#  "psi": 0.5,
#  "tau": 1.15,
#  "phi": 0.2,
#  "A": 53.2,
#  "B": -0.8668571428571438,
#  "delta": 0.05
# }
#
# ================================State Variables=================================
# x: [0.05, 0.95]
# v: [0.05, 0.95]
#
# =====================================Agents=====================================
# Agent Name: xi
# Agent(
#   (model): Sequential(
#     (linear_0): Linear(in_features=2, out_features=30, bias=True)
#     (activation_0): Tanh()
#     (linear_1): Linear(in_features=30, out_features=30, bias=True)
#     (activation_1): Tanh()
#     (linear_2): Linear(in_features=30, out_features=30, bias=True)
#     (activation_2): Tanh()
#     (linear_3): Linear(in_features=30, out_features=30, bias=True)
#     (activation_3): Tanh()
#     (final_layer): Linear(in_features=30, out_features=1, bias=True)
#     (positive_act): Softplus(beta=1.0, threshold=20.0)
#   )
# )
# Num parameters: 2911
# --------------------------------------------------------------------------------
# Agent Name: zeta
# Agent(
#   (model): Sequential(
#     (linear_0): Linear(in_features=2, out_features=30, bias=True)
#     (activation_0): Tanh()
#     (linear_1): Linear(in_features=30, out_features=30, bias=True)
#     (activation_1): Tanh()
#     (linear_2): Linear(in_features=30, out_features=30, bias=True)
#     (activation_2): Tanh()
#     (linear_3): Linear(in_features=30, out_features=30, bias=True)
#     (activation_3): Tanh()
#     (final_layer): Linear(in_features=30, out_features=1, bias=True)
#     (positive_act): Softplus(beta=1.0, threshold=20.0)
#   )
# )
# Num parameters: 2911
# --------------------------------------------------------------------------------
#
# ================================Agent Conditions================================
#
# ==============================Endogenous Variables==============================
# Endogenous Variable Name: p
# EndogVar(
#   (model): Sequential(
#     (linear_0): Linear(in_features=2, out_features=30, bias=True)
#     (activation_0): Tanh()
#     (linear_1): Linear(in_features=30, out_features=30, bias=True)
#     (activation_1): Tanh()
#     (linear_2): Linear(in_features=30, out_features=30, bias=True)
#     (activation_2): Tanh()
#     (linear_3): Linear(in_features=30, out_features=30, bias=True)
#     (activation_3): Tanh()
#     (final_layer): Linear(in_features=30, out_features=1, bias=True)
#     (positive_act): Softplus(beta=1.0, threshold=20.0)
#   )
# )
# Num parameters: 2911
# --------------------------------------------------------------------------------
# Endogenous Variable Name: r
# EndogVar(
#   (model): Sequential(
#     (linear_0): Linear(in_features=2, out_features=30, bias=True)
#     (activation_0): Tanh()
#     (linear_1): Linear(in_features=30, out_features=30, bias=True)
#     (activation_1): Tanh()
#     (linear_2): Linear(in_features=30, out_features=30, bias=True)
#     (activation_2): Tanh()
#     (linear_3): Linear(in_features=30, out_features=30, bias=True)
#     (activation_3): Tanh()
#     (final_layer): Linear(in_features=30, out_features=1, bias=True)
#   )
# )
# Num parameters: 2911
# --------------------------------------------------------------------------------
#
# ========================Endogenous Variables Conditions=========================
#
# ===================================Equations====================================
# eq_1:
# Raw input: $g &= \frac{1}{2*A} * (p - B) - \delta$
# Parsed: g=(1)/(2*A) * (p - B) - delta
# eq_2:
# Raw input: $\iota &= A * (g+\delta)^2 + B * (g+\delta)$
# Parsed: iota=A * (g+delta)**(2) + B * (g+delta)
# eq_3:
# Raw input: $\mu_v &= \lambda * (\bar{v} - v)$
# Parsed: muv=lbd * (v_mean - v)
# eq_4:
# Raw input: $\sigma_v &= \bar{\sigma_v} * \sqrt{v}$
# Parsed: sigv=sigv_mean * sqrt(v)
# eq_5:
# Raw input: $\hat{e} &= \rho^{1/\psi} * \xi^{(\psi-1)/\psi}$
# Parsed: e_hat=rho**(1/psi) * xi**((psi-1)/psi)
# eq_6:
# Raw input: $\hat{c} &= \rho^{1/\psi} * \zeta^{(\psi-1)/\psi}$
# Parsed: c_hat=rho**(1/psi) * zeta**((psi-1)/psi)
# eq_7:
# Raw input: $\sigma_{x,1} &= (1-x) * x * \frac{1-\gamma}{\gamma} * \left( \frac{1}{\xi} * \frac{\partial \xi}{\partial v} - \frac{1}{\zeta} * \frac{\partial \zeta}{\partial v} \right)$
# Parsed: sigxtop=(1-x) * x * (1-gamma)/(gamma) * ( (1)/(xi) * xi_v - (1)/(zeta) * zeta_v )
# eq_8:
# Raw input: $\sigma_{x,2} &= 1 - (1-x) * x * \frac{1-\gamma}{\gamma} * \left( \frac{1}{\xi} * \frac{\partial \xi}{\partial x} - \frac{1}{\zeta} * \frac{\partial \zeta}{\partial x} \right)$
# Parsed: sigxbot=1 - (1-x) * x * (1-gamma)/(gamma) * ( (1)/(xi) * xi_x - (1)/(zeta) * zeta_x )
# eq_9:
# Raw input: $\sigma_x &= \frac{\sigma_{x,1}}{\sigma_{x,2}} * \sigma_v$
# Parsed: sigx=(sigxtop)/(sigxbot) * sigv
# eq_10:
# Raw input: $\sigma_p &= \frac{1}{p} * \left( \frac{\partial p}{\partial v} * \sigma_v + \frac{\partial p}{\partial x} * \sigma_x \right)$
# Parsed: sigp=(1)/(p) * ( p_v * sigv + p_x * sigx )
# eq_11:
# Raw input: $\sigma_\xi &= \frac{1}{\xi} * \left( \frac{\partial \xi}{\partial v} * \sigma_v + \frac{\partial \xi}{\partial x} * \sigma_x \right)$
# Parsed: sigxi=(1)/(xi) * ( xi_v * sigv + xi_x * sigx )
# eq_12:
# Raw input: $\sigma_\zeta &= \frac{1}{\zeta} * \left( \frac{\partial \zeta}{\partial v} * \sigma_v + \frac{\partial \zeta}{\partial x} * \sigma_x \right)$
# Parsed: sigzeta=(1)/(zeta) * ( zeta_v * sigv + zeta_x * sigx )
# eq_13:
# Raw input: $\sigma_n &= \sigma + \sigma_p + \frac{\sigma_x}{x}$
# Parsed: sign=sigma + sigp + (sigx)/(x)
# eq_14:
# Raw input: $\pi &= \gamma * \sigma_n + (\gamma-1) * \sigma_\xi$
# Parsed: signxi=gamma * sign + (gamma-1) * sigxi
# eq_15:
# Raw input: $\sigma_w &= \frac{\pi}{\gamma} - \frac{\gamma-1}{\gamma} *  \sigma_\zeta$
# Parsed: sigw=(signxi)/(gamma) - (gamma-1)/(gamma) *  sigzeta
# eq_16:
# Raw input: $\mu_w &= r + \pi * \sigma_w$
# Parsed: muw=r + signxi * sigw
# eq_17:
# Raw input: $\mu_n &= r + \frac{\gamma}{x^2} * (\phi * v)^2 + \pi * \sigma_n$
# Parsed: mun=r + (gamma)/(x**(2)) * (phi * v)**(2) + signxi * sign
# eq_18:
# Raw input: $\tilde{\sigma_n} &= \frac{\phi}{x} * v$
# Parsed: signtilde=(phi)/(x) * v
# eq_19:
# Raw input: $\mu_x &= x * \left(\mu_n - \hat{e} - \tau + \frac{a-\iota}{p} - r - \pi * (\sigma+\sigma_p) - \frac{\gamma}{x} * (\phi * v)^2 + (\sigma + \sigma_p)^2 - \sigma_n * (\sigma + \sigma_p)\right)$
# Parsed: mux=x * (mun - e_hat - tau + (a-iota)/(p) - r - signxi * (sigma+sigp) - (gamma)/(x) * (phi * v)**(2) + (sigma + sigp)**(2) - sign * (sigma + sigp))
# eq_20:
# Raw input: $\mu_p &= \frac{1}{p} * \left( \mu_v * \frac{\partial p}{\partial v} + \mu_x * \frac{\partial p}{\partial x} + \frac{1}{2} * \left( \sigma_v^2 * \frac{\partial^2 p}{\partial v^2} + 2 * \sigma_v * \sigma_x * \frac{\partial^2 p}{\partial v \partial x} + \sigma_x^2 * \frac{\partial^2 p}{\partial x^2} \right)\right)$
# Parsed: mup=(1)/(p) * ( muv * p_v + mux * p_x + (1)/(2) * ( sigv**(2) * p_vv + 2 * sigv * sigx * p_vx + sigx**(2) * p_xx ))
# eq_21:
# Raw input: $\mu_\xi &= \frac{1}{\xi} * \left( \mu_v * \frac{\partial \xi}{\partial v} + \mu_x * \frac{\partial \xi}{\partial x} + \frac{1}{2} * \left( \sigma_v^2 * \frac{\partial^2 \xi}{\partial v^2} + 2 * \sigma_v * \sigma_x * \frac{\partial^2 \xi}{\partial v \partial x} + \sigma_x^2 * \frac{\partial^2 \xi}{\partial x^2} \right)\right)$
# Parsed: muxi=(1)/(xi) * ( muv * xi_v + mux * xi_x + (1)/(2) * ( sigv**(2) * xi_vv + 2 * sigv * sigx * xi_vx + sigx**(2) * xi_xx ))
# eq_22:
# Raw input: $\mu_\zeta &= \frac{1}{\zeta} * \left( \mu_v * \frac{\partial \zeta}{\partial v} + \mu_x * \frac{\partial \zeta}{\partial x} + \frac{1}{2} * \left( \sigma_v^2 * \frac{\partial^2 \zeta}{\partial v^2} + 2 * \sigma_v * \sigma_x * \frac{\partial^2 \zeta}{\partial v \partial x} + \sigma_x^2 * \frac{\partial^2 \zeta}{\partial x^2} \right)\right)$
# Parsed: muzeta=(1)/(zeta) * ( muv * zeta_v + mux * zeta_x + (1)/(2) * ( sigv**(2) * zeta_vv + 2 * sigv * sigx * zeta_vx + sigx**(2) * zeta_xx ))
#
# ==============================Endogenous Equations==============================
# endogeq_1:
# Raw input: $a - \iota &= p * (\hat{e} * x + \hat{c} * (1-x))$
# Parsed: a - iota=p * (e_hat * x + c_hat * (1-x))
# Loss weight: 1.0
# --------------------------------------------------------------------------------
# endogeq_2:
# Raw input: $\sigma + \sigma_p &= \sigma_n * x + \sigma_w * (1-x)$
# Parsed: sigma + sigp=sign * x + sigw * (1-x)
# Loss weight: 1.0
# --------------------------------------------------------------------------------
# endogeq_3:
# Raw input: $\frac{a-\iota}{p} + g + \mu_p + \sigma * \sigma_p - r &= (\sigma + \sigma_p) * \pi + \gamma * \frac{1}{x} * (\phi * v)^2$
# Parsed: (a-iota)/(p) + g + mup + sigma * sigp - r=(sigma + sigp) * signxi + gamma * (1)/(x) * (phi * v)**(2)
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ==================================Constraints===================================
#
# =================================HJB Equations==================================
# hjbeq_1:
# Raw input: $\frac{\hat{e}^{1-\psi}}{1-\psi} * \rho * \xi^{\psi-1} + \frac{\tau}{1-\gamma} * \left(\left(\frac{\zeta}{\xi} \right)^{1-\gamma}-1 \right) + \mu_n - \hat{e} + \mu_\xi - \frac{\gamma}{2} * \left( \sigma_n^2 + \sigma_\xi^2 - 2 * \frac{1-\gamma}{\gamma} * \sigma_n * \sigma_\xi + \tilde{\sigma_n}^2 \right) - \frac{\rho}{1-\psi}$;
# Parsed: (e_hat**(1-psi))/(1-psi) * rho * xi**(psi-1) + (tau)/(1-gamma) * (((zeta)/(xi) )**(1-gamma)-1 ) + mun - e_hat + muxi - (gamma)/(2) * ( sign**(2) + sigxi**(2) - 2 * (1-gamma)/(gamma) * sign * sigxi + signtilde**(2) ) - (rho)/(1-psi)
# Loss weight: 1.0
# --------------------------------------------------------------------------------
# hjbeq_2:
# Raw input: $\frac{\hat{c}^{1-\psi}}{1-\psi} * \rho * \zeta^{\psi-1} + \mu_w - \hat{c} + \mu_\zeta - \frac{\gamma}{2} * \left( \sigma_w^2 + \sigma_\zeta^2 - 2 * \frac{1-\gamma}{\gamma} * \sigma_w * \sigma_\zeta \right) - \frac{\rho}{1-\psi}$;
# Parsed: (c_hat**(1-psi))/(1-psi) * rho * zeta**(psi-1) + muw - c_hat + muzeta - (gamma)/(2) * ( sigw**(2) + sigzeta**(2) - 2 * (1-gamma)/(gamma) * sigw * sigzeta ) - (rho)/(1-psi)
# Loss weight: 1.0
# --------------------------------------------------------------------------------
#
# ====================================Systems=====================================
#
#
# ====================================Training====================================
# Total loss: 0.0013: 100%|██████████| 10000/10000 [13:03<00:00, 12.76it/s]
# C:\Users\User\AppData\Local\Temp\ipykernel_17132\2761718623.py:69: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pde_model.load_model(torch.load("./models/ditella_with_investments2/model_best.pt"))
# training finished, total time :: 783.7146692276001
# Best model saved to ./models/ditella_with_investments2/model_best.pt if valid
# Model saved to ./models/ditella_with_investments2/model.pt
# Model loaded
# ===================================Evaluating===================================
# loss :: endogeq_1: 0.0001,
# endogeq_2: 0.0000,
# endogeq_3: 0.0000,
# hjbeq_1: 0.0000,
# hjbeq_2: 0.0000,
# total_loss: 0.0002

# %%
plot_loss_df(fn="./models/ditella_with_investments2/model_min_loss.csv", loss_plot_fn="./models/ditella_with_investments2/model_min_loss.png")
plot_loss_df(fn="./models/ditella_with_investments2/model_loss_weight.csv", loss_plot_fn="./models/ditella_with_investments2/model_loss_weight.png", log_loss=False)
pde_model.plot_vars([r"$\xi$", r"$\zeta$", "p", 
                     r"$\sigma+\sigma_p = \sigma + \sigma_p$", r"$\pi$", "r"], ncols=3)

# %%
fig, ax = plt.subplots(2, 3, figsize=(18, 12))
for x_val, linestyle in [(0.05, "-"), (0.1, ":"), (0.2, "--")]:
    sv = torch.ones((100, 2), device=pde_model.device) * x_val
    sv[:, 1] = torch.linspace(0.05, 0.95, 100)
    for i, sv_name in enumerate(pde_model.state_variables):
        pde_model.variable_val_dict[sv_name] = sv[:, i:i+1]
    pde_model.update_variables(sv)
    p = pde_model.variable_val_dict["p"]
    sigx = pde_model.variable_val_dict["sigx"]
    omega = pde_model.variable_val_dict["xi"] / pde_model.variable_val_dict["zeta"]
    ax[0][0].plot(sv[:, 1].detach().cpu().numpy(), p.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"x={x_val}")
    ax[0][1].plot(sv[:, 1].detach().cpu().numpy(), sigx.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"x={x_val}")
    ax[0][2].plot(sv[:, 1].detach().cpu().numpy(), omega.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"x={x_val}")
    ax[0][0].set_title(r"p")
    ax[0][1].set_title(r"$\sigma_x$")
    ax[0][2].set_title(r"$\Omega = \xi/\zeta$")
    ax[0][0].legend()
    ax[0][1].legend()
    ax[0][2].legend()

for v_val, linestyle in [(0.1, "-"), (0.25, ":"), (0.6, "--")]:
    sv = torch.ones((100, 2), device=pde_model.device) * v_val
    sv[:, 0] = torch.linspace(0.05, 0.95, 100)
    for i, sv_name in enumerate(pde_model.state_variables):
        pde_model.variable_val_dict[sv_name] = sv[:, i:i+1]
    pde_model.update_variables(sv)
    p = pde_model.variable_val_dict["p"]
    sigx = pde_model.variable_val_dict["sigx"]
    omega = pde_model.variable_val_dict["xi"] / pde_model.variable_val_dict["zeta"]
    ax[1][0].plot(sv[:, 0].detach().cpu().numpy(), p.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"v={v_val}")
    ax[1][1].plot(sv[:, 0].detach().cpu().numpy(), sigx.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"v={v_val}")
    ax[1][2].plot(sv[:, 0].detach().cpu().numpy(), omega.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"v={v_val}")
    ax[1][0].set_title(r"p")
    ax[1][1].set_title(r"$\sigma_x$")
    ax[1][2].set_title(r"$\Omega = \xi/\zeta$")
    ax[1][0].legend()
    ax[1][1].legend()
    ax[1][2].legend()

# %%
fig, ax = plt.subplots(2, 3, figsize=(18, 12))
for x_val, linestyle in [(0.05, "-"), (0.1, ":"), (0.2, "--")]:
    sv = torch.ones((100, 2), device=pde_model.device) * x_val
    sv[:, 1] = torch.linspace(0.05, 0.95, 100)
    for i, sv_name in enumerate(pde_model.state_variables):
        pde_model.variable_val_dict[sv_name] = sv[:, i:i+1]
    pde_model.update_variables(sv)
    sigsigp = pde_model.variable_val_dict["sigma"] + pde_model.variable_val_dict["sigp"]
    pi = pde_model.variable_val_dict["signxi"]
    r = pde_model.variable_val_dict["r"]
    ax[0][0].plot(sv[:, 1].detach().cpu().numpy(), sigsigp.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"x={x_val}")
    ax[0][1].plot(sv[:, 1].detach().cpu().numpy(), pi.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"x={x_val}")
    ax[0][2].plot(sv[:, 1].detach().cpu().numpy(), r.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"x={x_val}")
    ax[0][0].set_title(r"$\sigma+\sigma_p$")
    ax[0][1].set_title(r"$\pi$")
    ax[0][2].set_title("r")
    ax[0][0].legend()
    ax[0][1].legend()
    ax[0][2].legend()
for v_val, linestyle in [(0.1, "-"), (0.25, ":"), (0.6, "--")]:
    sv = torch.ones((100, 2), device=pde_model.device) * v_val
    sv[:, 0] = torch.linspace(0.05, 0.95, 100)
    for i, sv_name in enumerate(pde_model.state_variables):
        pde_model.variable_val_dict[sv_name] = sv[:, i:i+1]
    pde_model.update_variables(sv)
    sigsigp = pde_model.variable_val_dict["sigma"] + pde_model.variable_val_dict["sigp"]
    pi = pde_model.variable_val_dict["signxi"]
    r = pde_model.variable_val_dict["r"]
    ax[1][0].plot(sv[:, 0].detach().cpu().numpy(), sigsigp.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"v={v_val}")
    ax[1][1].plot(sv[:, 0].detach().cpu().numpy(), pi.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"v={v_val}")
    ax[1][2].plot(sv[:, 0].detach().cpu().numpy(), r.detach().cpu().numpy().reshape(-1), linestyle=linestyle, label=f"v={v_val}")
    ax[1][0].set_title(r"$\sigma+\sigma_p$")
    ax[1][1].set_title(r"$\pi$")
    ax[1][2].set_title("r")
    ax[1][0].legend()
    ax[1][1].legend()
    ax[1][2].legend()

# %%
import pandas as pd
import matplotlib.pyplot as plt
loss_df_no_adaption = pd.read_csv("./models/ditella_with_investments/model_min_loss.csv").dropna().reset_index(drop=True)
loss_df_adaption = pd.read_csv("./models/ditella_with_investments2/model_min_loss.csv").dropna().reset_index(drop=True)
print("Min losses:")
print("no adaption:", loss_df_no_adaption["total_loss"].min())
print("with adaption:", loss_df_adaption["total_loss"].min())
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
losses_to_plot = list(loss_df_no_adaption.columns)
losses_to_plot.remove("epoch")
losses_to_plot.remove("endogeq_2")
titles = ["Loss No Adaption", "Loss With Adaption"]
for i, loss_df in enumerate([loss_df_no_adaption, loss_df_adaption]):
    epochs = loss_df["epoch"]
    for loss in losses_to_plot:
        ax[i].plot(epochs, loss_df[loss], label=loss)
    for j in range(1, 15):
        ax[i].axvline(j*100, color="black", linestyle="dashed")
    ax[i].set_yscale("log")
    ax[i].set_xlabel("epoch")
    ax[i].set_ylabel("Loss")
    ax[i].legend()
    ax[i].set_title(titles[i])
plt.tight_layout()
plt.show()
# Out:
# Min losses:
# no adaption: 0.0001577587827341
# with adaption: 0.0001618339156266

# %%
loss_df_no_adaption = pd.read_csv("./models/ditella_with_investments/model_min_loss.csv").dropna().reset_index(drop=True)
loss_df_adaption = pd.read_csv("./models/ditella_with_investments2/model_min_loss.csv").dropna().reset_index(drop=True)
print("Min losses:")
print("no adaption:", loss_df_no_adaption["total_loss"].min())
print("with adaption:", loss_df_adaption["total_loss"].min())
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
losses_to_plot = list(loss_df_no_adaption.columns)
losses_to_plot.remove("epoch")
losses_to_plot.remove("endogeq_2")
colors = ["blue", "orange", "green", "red", "purple"]
alphas = [0.5, 1.0]
widths = [2, 4]
linestyles = ["-", "--"]
for i, loss_df in enumerate([loss_df_no_adaption, loss_df_adaption]):
    for j, loss in enumerate(losses_to_plot):
        ax.plot(loss_df["epoch"], loss_df[loss], label=loss, color=colors[j], linestyle=linestyles[i], alpha=alphas[i])
for j in range(1, 15):
    ax.axvline(j*100, color="black", linestyle="dashed")
ax.set_yscale("log")
ax.set_xlabel("epoch")
ax.set_ylabel("Loss")
ax.legend()
ax.set_title("Losses")
plt.tight_layout()
plt.show()
# Out:
# Min losses:
# no adaption: 0.0001577587827341
# with adaption: 0.0001618339156266

# %%
loss_weight_df = pd.read_csv("./models/ditella_with_investments2/model_loss_weight.csv").dropna().reset_index(drop=True)
loss_weight_df = loss_weight_df[loss_weight_df["epoch"] <= 1000]
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
losses_to_plot = list(loss_weight_df.columns)
losses_to_plot.remove("epoch")
# losses_to_plot.remove("endogeq_2")
epochs = loss_weight_df["epoch"]
for loss in losses_to_plot:
    ax.plot(epochs, loss_weight_df[loss], label=loss)
for j in range(1, 10):
    ax.axvline(j*100, color="black", linestyle="dashed")
# ax.set_yscale("log")
ax.set_xlabel("epoch")
ax.set_ylabel("Loss")
ax.legend()
ax.set_title("Adaptive Loss weights")
plt.tight_layout()
plt.show()
