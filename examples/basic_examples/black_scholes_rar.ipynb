# %% [markdown]
# # Black Scholes Equation
# $$\frac{\partial V}{\partial t} + \frac{1}{2} \sigma^2 S^2 \frac{\partial^2 V}{\partial S^2} + rS \frac{\partial V}{\partial S} - rV = 0$$
#
# s.t. $V(S, 1) = \max(S-K, 0)$
#
# We assume $S\in[0,1], T\in[0,1]$ ($T$ is normalized)
#
# The constants are set to be $\sigma=0.1$, $r=0.05$, $K=0.5$

# %%
import os
import numpy as np
import torch
import matplotlib.pyplot as plt
from deep_macrofin import PDEModel
from deep_macrofin import ActivationType, OptimizerType, Comparator, SamplingMethod, set_seeds, plot_loss_df

# %%
set_seeds(0)
pde = PDEModel("black_scholes", 
               config={
                    "batch_size": 20, "num_epochs": 2000, "optimizer_type": OptimizerType.Adam,
                    "sampling_method": SamplingMethod.RARD
                })
pde.set_state(["S", "t"], {"S": [0., 1.], "t": [0., 1.]})
pde.add_endog("V")
pde.add_endog_equation(r"$\frac{\partial V}{\partial t} + \frac{1}{2} * 0.01 * S^2 * \frac{\partial^2 V}{\partial S^2} + 0.05 * S * \frac{\partial V}{\partial S} - 0.05 * V = 0$")

maturity_sv = torch.ones((100, 2))
maturity_sv[:, 0] = torch.Tensor(np.linspace(0, 1, 100))
maturity_prices = torch.where(maturity_sv[:, 0:1] > 0.5, maturity_sv[:, 0:1] - 0.5, 0)

pde.add_endog_condition("V", 
                        "V(SV)", {"SV": maturity_sv},
                        Comparator.EQ,
                        "maturity_prices", {"maturity_prices": maturity_prices},
                        label="bc1")

print(pde)
if not os.path.exists("./models/black_scholes/model_rar.pt"):
    pde.train_model("./models/black_scholes", "model_rar.pt", True)
    pde.load_model(torch.load("./models/black_scholes/model_rar_best.pt"))
    pde.eval_model(True)
else:
    pde.load_model(torch.load("./models/black_scholes/model_rar_best.pt"))
    pde.eval_model(True)
# Out:
# =========================Summary of Model black_scholes=========================
# Config: {
#  "batch_size": 20,
#  "num_epochs": 2000,
#  "lr": 0.001,
#  "loss_log_interval": 100,
#  "optimizer_type": "Adam",
#  "sampling_method": "RAR-D",
#  "refinement_sample_interval": 200
# }
# Latex Variable Mapping:
# {}
# User Defined Parameters:
# {}
#
# ================================State Variables=================================
# S: [0.0, 1.0]
# t: [0.0, 1.0]
#
# =====================================Agents=====================================
#
# ================================Agent Conditions================================
#
# ==============================Endogenous Variables==============================
# Endogenous Variable Name: V
# EndogVar(
#   (model): Sequential(
#     (linear_0): Linear(in_features=2, out_features=30, bias=True)
#     (activation_0): Tanh()
#     (linear_1): Linear(in_features=30, out_features=30, bias=True)
#     (activation_1): Tanh()
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5), subplot_kw={"projection": "3d"})
pde.endog_vars["V"].plot("V", {"S": [0., 1.], "t": [0., 1.]}, ax=ax)
plt.subplots_adjust()
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))
s_dim = np.linspace(0, 1, 100)
zero_t = torch.zeros((100, 2))
zero_t[:, 0] = torch.Tensor(s_dim)
V_zero_t = pde.endog_vars["V"].forward(zero_t).detach().cpu().numpy()

one_t = torch.ones((100, 2))
one_t[:, 0] = torch.Tensor(s_dim)
V_one_t = pde.endog_vars["V"].forward(one_t).detach().cpu().numpy()
ax.plot(s_dim, V_zero_t, label="t=0")
ax.plot(s_dim, V_one_t, label="t=1")
ax.legend()
plt.subplots_adjust()
plt.show()

# %%
plot_loss_df(fn="./models/black_scholes/model_rar_loss.csv", loss_plot_fn="./models/black_scholes/model_rar_loss.png")

# %%
set_seeds(0)
pde = PDEModel("black_scholes", 
               config={
                    "batch_size": 20, "num_epochs": 2000, "optimizer_type": OptimizerType.Adam,
                    "sampling_method": SamplingMethod.RARG
                })
pde.set_state(["S", "t"], {"S": [0., 1.], "t": [0., 1.]})
pde.add_endog("V")
pde.add_endog_equation(r"$\frac{\partial V}{\partial t} + \frac{1}{2} * 0.01 * S^2 * \frac{\partial^2 V}{\partial S^2} + 0.05 * S * \frac{\partial V}{\partial S} - 0.05 * V = 0$")

maturity_sv = torch.ones((100, 2))
maturity_sv[:, 0] = torch.Tensor(np.linspace(0, 1, 100))
maturity_prices = torch.where(maturity_sv[:, 0:1] > 0.5, maturity_sv[:, 0:1] - 0.5, 0)

pde.add_endog_condition("V", 
                        "V(SV)", {"SV": maturity_sv},
                        Comparator.EQ,
                        "maturity_prices", {"maturity_prices": maturity_prices},
                        label="bc1")

print(pde)
if not os.path.exists("./models/black_scholes/model_rarg.pt"):
    pde.train_model("./models/black_scholes", "model_rarg.pt", True)
    pde.load_model(torch.load("./models/black_scholes/model_rarg_best.pt"))
    pde.eval_model(True)
else:
    pde.load_model(torch.load("./models/black_scholes/model_rarg_best.pt"))
    pde.eval_model(True)
# Out:
# =========================Summary of Model black_scholes=========================
# Config: {
#  "batch_size": 20,
#  "num_epochs": 2000,
#  "lr": 0.001,
#  "loss_log_interval": 100,
#  "optimizer_type": "Adam",
#  "sampling_method": "RAR-G",
#  "refinement_sample_interval": 200
# }
# Latex Variable Mapping:
# {}
# User Defined Parameters:
# {}
#
# ================================State Variables=================================
# S: [0.0, 1.0]
# t: [0.0, 1.0]
#
# =====================================Agents=====================================
#
# ================================Agent Conditions================================
#
# ==============================Endogenous Variables==============================
# Endogenous Variable Name: V
# EndogVar(
#   (model): Sequential(
#     (linear_0): Linear(in_features=2, out_features=30, bias=True)
#     (activation_0): Tanh()
#     (linear_1): Linear(in_features=30, out_features=30, bias=True)
#     (activation_1): Tanh()
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5), subplot_kw={"projection": "3d"})
pde.endog_vars["V"].plot("V", {"S": [0., 1.], "t": [0., 1.]}, ax=ax)
plt.subplots_adjust()
plt.show()

# %%
plot_loss_df(fn="./models/black_scholes/model_rarg_loss.csv", loss_plot_fn="./models/black_scholes/model_rarg_loss.png")
